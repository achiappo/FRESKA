# %%
import numpy as np
from math import log10
import pylab as plt
from scipy.interpolate import interp1d as interp
from scipy.optimize import brentq, minimize_scalar
from profiles import build_profile, build_kernel
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter

# %matplotlib inline

# %%
directory = '/home/andrea/Desktop/work/DWARF/dsphsim/'
rh = 0.04
D = 39.81
theta = 2*rh/D

# %%
dm = build_profile('NFW')
st = build_profile('plummer',**{'rh':rh}) # Plummer Stellar profile
kr = build_kernel('iso') # isotropic kernel
dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf, 'with_errs':False}
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

# %%
R, v = np.loadtxt(directory+'Ret2_data/dsph_001.txt',usecols=(5, 7),unpack=True)
dv = np.zeros_like(v)

# %%
LL = GaussianLikelihood([R, v, dv, 0.], Sigma)
LL.set_free('dm_r0')
global global_loglike
global_loglike = LL
M = MinuitFitter(LL)

# %% [raw]
# dm_true = build_profile('NFW')
# rvmax = 0.757
# vmax = 10.4
# rs = rvmax/2.163
# rhos = 4.625 * (vmax/rs)**2 / (4*np.pi*4.302e-6)
# dm_true.r0 = rs
# dm_true.rho0 = rhos
# Jtrue = log10(dm_true.Jfactor(**dwarf_props))
# print 'rs = %.2f, rhos = %.2e, J = %.2f'%(rs,rhos,Jtrue)

# %% [raw]
# # J
# M.set_value('J',18)
# M.set_error('J',0.01)
# #M.set_fixed('J')
# #M.set_bound('J',(15,22))
# # r0
# M.set_value('dm_r0',rh*4.)
# M.set_error('dm_r0',0.01)
# #M.set_bound('dm_r0',(R.min(),R.max()*100))
# M.settings['print_level'] = 1

# %% [raw]
# LL.set_free('dm_a')
# LL.set_free('dm_b')
# LL.set_free('dm_c')
#
# # a
# M.set_value('dm_a',1.)
# M.set_error('dm_a',0.01)
# #M.set_bound('dm_a',(1e-10,10))
# # b
# M.set_value('dm_b',3.)
# M.set_error('dm_b',0.01)
# #M.set_bound('dm_b',(1e-10,10))
# # c
# M.set_value('dm_c',1.)
# M.set_error('dm_c',0.01)
# #M.set_bound('dm_c',(1e-10,10))

# %% [raw]
# M.settings

# %% [raw]
# M.set_minuit(**{'tol':1e3,'strategy':1})
# BF = M.migrad_min()

# %% [raw]
# M.minuit.hesse()

# %% [raw]
# J_min = BF[1][2]['value']
# J_r0 = BF[1][4]['value']
# minrho = lambda rho : abs(J_min-log10(dm.Jfactor(D, theta, np.inf, False))-2*rho)
# J_rho0 = 10**minimize_scalar(minrho).x
# print '%g %g %g'%(J_min,J_r0,J_rho0)

# %% [raw]
# M.minuit.tol = 1e4
# J, L = M.minos_profile('J',**{'bound':2, 'bins':10, 'subtract_min':True})

# %%
J_array = np.linspace(15,18,10)
J_new = np.empty([0])
L_arr  = np.empty([0])
a_arr  = np.empty([0])
b_arr  = np.empty([0])
c_arr  = np.empty([0])
r_arr = np.empty([0])

# %%
LL = GaussianLikelihood([R, v, dv, 0.], Sigma)
LL.set_free('dm_r0')
LL.set_free('dm_a')
LL.set_free('dm_b')
LL.set_free('dm_c')
global global_loglike
global_loglike = LL

# %%
for J in J_array:
    M = MinuitFitter(LL)
    # J
    M.set_value('J',J)
    M.set_fixed('J')
    # r0
    M.set_value('dm_r0',rh*4.)
    M.set_error('dm_r0',0.01)
    # a
    M.set_value('dm_a',1.)
    M.set_error('dm_a',0.01)
    # b
    M.set_value('dm_b',3.)
    M.set_error('dm_b',0.01)
    # c
    M.set_value('dm_c',1.)
    M.set_error('dm_c',0.01)
    
    M.settings['print_level'] = 1
    M.set_minuit(**{'tol':1,'strategy':2})
    valid = False
    while not valid:
        BF = M.migrad_min()
        valid = BF[0]['is_valid']
        M.minuit.tol *= 10
    else:
        J_new = np.append(J_new,J)
        L_arr = np.append(L_arr,BF[0]['fval'])
        a_arr = np.append(a_arr,BF[1][0]['value'])
        b_arr = np.append(b_arr,BF[1][1]['value'])
        c_arr = np.append(c_arr,BF[1][3]['value'])
        r_arr = np.append(r_arr,BF[1][4]['value'])
# Out:
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.321235
#      dm_b = +0.485345
#         J = +15.000000
#      dm_c = +0.709285
#     dm_r0 = +0.231336
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -nan
#      dm_b = -nan
#         J = +15.000000
#      dm_c = -nan
#     dm_r0 = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.529498
#      dm_b = +1.082683
#         J = +15.000000
#      dm_c = +1.930704
#     dm_r0 = +0.286249
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540389
#      dm_b = +1.113890
#         J = +15.000000
#      dm_c = +1.994581
#     dm_r0 = +0.289120
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540934
#      dm_b = +1.115450
#         J = +15.000000
#      dm_c = +1.997775
#     dm_r0 = +0.289264
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540961
#      dm_b = +1.115528
#         J = +15.000000
#      dm_c = +1.997934
#     dm_r0 = +0.289271
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540963
#      dm_b = +1.115532
#         J = +15.000000
#      dm_c = +1.997942
#     dm_r0 = +0.289272
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540963
#      dm_b = +1.115532
#         J = +15.000000
#      dm_c = +1.997943
#     dm_r0 = +0.289272
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.540963
#      dm_b = +1.115533
#         J = +15.000000
#      dm_c = +1.997943
#     dm_r0 = +0.289272
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.427952
#      dm_b = +0.497051
#         J = +15.000000
#      dm_c = +0.737640
#     dm_r0 = +0.308421
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.480502
#      dm_b = +0.498560
#         J = +15.000000
#      dm_c = +0.741067
#     dm_r0 = +0.311491
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.483129
#      dm_b = +0.498636
#         J = +15.000000
#      dm_c = +0.741238
#     dm_r0 = +0.311644
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.483261
#      dm_b = +0.498640
#         J = +15.000000
#      dm_c = +0.741247
#     dm_r0 = +0.311652
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.483267
#      dm_b = +0.498640
#         J = +15.000000
#      dm_c = +0.741247
#     dm_r0 = +0.311652
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.483268
#      dm_b = +0.498640
#         J = +15.000000
#      dm_c = +0.741247
#     dm_r0 = +0.311652
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1217.98695776</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 269</td>
#                 <td title="Number of call in last migrad">NCALLS = 256</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 5.04324798633</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e-05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#GpDdrPaPPT').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.376949e+00</td>
#                 <td>8.171202e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>4.668685e-01</td>
#                 <td>1.657303e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>6.691140e-01</td>
#                 <td>4.106950e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>2.470212e-01</td>
#                 <td>1.060660e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="GpDdrPaPPT" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.377e+00 & 8.171e-01 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 4.669e-01 & 1.657e-02 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 6.691e-01 & 4.107e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 2.470e-01 & 1.061e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.429142
#      dm_b = +0.497052
#         J = +15.000000
#      dm_c = +0.737643
#     dm_r0 = +0.308426
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.481751
#      dm_b = +0.498561
#         J = +15.000000
#      dm_c = +0.741069
#     dm_r0 = +0.311496
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.484382
#      dm_b = +0.498637
#         J = +15.000000
#      dm_c = +0.741241
#     dm_r0 = +0.311650
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.484513
#      dm_b = +0.498640
#         J = +15.000000
#      dm_c = +0.741249
#     dm_r0 = +0.311658
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.080918
#      dm_b = +5253231.920503
#         J = +16.666667
#      dm_c = +79326344.410738
#     dm_r0 = -34751406.907654
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.105973
#      dm_b = +5253855.819580
#         J = +16.666667
#      dm_c = +79335765.591657
#     dm_r0 = -34755534.153139
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107225
#      dm_b = +5253887.014534
#         J = +16.666667
#      dm_c = +79336236.650703
#     dm_r0 = -34755740.515414
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107288
#      dm_b = +5253888.574281
#         J = +16.666667
#      dm_c = +79336260.203655
#     dm_r0 = -34755750.833527
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107291
#      dm_b = +5253888.652269
#         J = +16.666667
#      dm_c = +79336261.381303
#     dm_r0 = -34755751.349433
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107291
#      dm_b = +5253888.656168
#         J = +16.666667
#      dm_c = +79336261.440185
#     dm_r0 = -34755751.375228
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107291
#      dm_b = +5253888.656363
#         J = +16.666667
#      dm_c = +79336261.443129
#     dm_r0 = -34755751.376518
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107291
#      dm_b = +5253888.656373
#         J = +16.666667
#      dm_c = +79336261.443277
#     dm_r0 = -34755751.376583
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +336.107291
#      dm_b = +5253888.656373
#         J = +16.666667
#      dm_c = +79336261.443284
#     dm_r0 = -34755751.376586
#
#   return self.minuit.migrad(**kwargs)
# likelihood.py:62: RuntimeWarning: divide by zero encountered in log
#   res = np.log(S) + ((v-vsys)**2)/S
# likelihood.py:62: RuntimeWarning: divide by zero encountered in divide
#   res = np.log(S) + ((v-vsys)**2)/S
# likelihood.py:62: RuntimeWarning: invalid value encountered in add
#   res = np.log(S) + ((v-vsys)**2)/S
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +668.725738
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -418.485376
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5561.175752
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -5310.935390
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +54485.675890
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -54235.435529
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +543730.677273
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -543480.436912
#      dm_b = +1.696266
#         J = +16.666667
#      dm_c = +1.071146
#     dm_r0 = +0.077128
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +827.589896
#      dm_b = +1.696586
#         J = +16.666667
#      dm_c = +1.071166
#     dm_r0 = +0.077109
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# ...
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>3.126189e-02</td>
#                 <td>8.635324e-05</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>1.639139e+00</td>
#                 <td>4.931123e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.800000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.266846e+00</td>
#                 <td>7.173916e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>5.943720e-01</td>
#                 <td>1.320072e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="KmmTzpxioe" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 3.126e-02 & 8.635e-05 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 1.639e+00 & 4.931e-02 &  &  &  &  & \\
# \hline
# 3 & J & 1.800e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.267e+00 & 7.174e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 5.944e-01 & 1.320e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +542832.737889
#      dm_b = -95039.644835
#         J = +18.000000
#      dm_c = +65373.329833
#     dm_r0 = -7339.227191
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +569974.373221
#      dm_b = -99791.709028
#         J = +18.000000
#      dm_c = +68641.932991
#     dm_r0 = -7706.218268
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571331.454987
#      dm_b = -100029.312238
#         J = +18.000000
#      dm_c = +68805.363149
#     dm_r0 = -7724.567822
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571399.309076
#      dm_b = -100041.192398
#         J = +18.000000
#      dm_c = +68813.534657
#     dm_r0 = -7725.485299
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.701780
#      dm_b = -100041.786406
#         J = +18.000000
#      dm_c = +68813.943232
#     dm_r0 = -7725.531173
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.871415
#      dm_b = -100041.816106
#         J = +18.000000
#      dm_c = +68813.963661
#     dm_r0 = -7725.533467
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.879897
#      dm_b = -100041.817591
#         J = +18.000000
#      dm_c = +68813.964682
#     dm_r0 = -7725.533582
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.880321
#      dm_b = -100041.817666
#         J = +18.000000
#      dm_c = +68813.964733
#     dm_r0 = -7725.533587
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.880342
#      dm_b = -100041.817669
#         J = +18.000000
#      dm_c = +68813.964736
#     dm_r0 = -7725.533588
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +571402.880343
#      dm_b = -100041.817670
#         J = +18.000000
#      dm_c = +68813.964736
#     dm_r0 = -7725.533588
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1198.05357697</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 792</td>
#                 <td title="Number of call in last migrad">NCALLS = 122</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 3.50063310164e-08</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.05</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#hKhzFKIiCz').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>3.126166e-02</td>
#                 <td>8.400208e-06</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>1.639020e+00</td>
#                 <td>6.137333e-05</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.800000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.266675e+00</td>
#                 <td>6.975253e-05</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>5.943546e-01</td>
#                 <td>7.948630e-04</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="hKhzFKIiCz" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 3.126e-02 & 8.400e-06 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 1.639e+00 & 6.137e-05 &  &  &  &  & \\
# \hline
# 3 & J & 1.800e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.267e+00 & 6.975e-05 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 5.944e-01 & 7.949e-04 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1198.05335985</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 919</td>
#                 <td title="Number of call in last migrad">NCALLS = 127</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.04541766867e-10</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#sUCbAXDxZD').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>3.126112e-02</td>
#                 <td>5.402087e-08</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>1.638857e+00</td>
#                 <td>4.219638e-06</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.800000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.266791e+00</td>
#                 <td>3.254378e-06</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>5.943021e-01</td>
#                 <td>1.102637e-05</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="sUCbAXDxZD" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 3.126e-02 & 5.402e-08 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 1.639e+00 & 4.220e-06 &  &  &  &  & \\
# \hline
# 3 & J & 1.800e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.267e+00 & 3.254e-06 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 5.943e-01 & 1.103e-05 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>

# %%
J_array = np.asarray(J_new)
Like_array = np.asarray(L_arr)
new_Like = interp(J_array,Like_array-Like_array.min())

# %%
eval_Like_J = np.linspace(J_array.min(),J_array.max(),1e3)
min_Like_J  = new_Like(eval_Like_J).min()
J_min       = eval_Like_J[np.where(new_Like(eval_Like_J)==min_Like_J)[0][0]]

# %%
new_J = np.linspace(J_array.min(),J_array.max())
plt.plot(new_J, new_Like(new_J))
plt.plot(J_min,0,'r*')
plt.ylim(-0.5,12);

# %% [raw]
# err = BF[1][0]['error']
# J_array = np.linspace(J_min-err*3,J_min+err*3)
# for J in J_array:
#
# M.minuit.draw_mnprofile('J', bound=(17,22), subtract_min=True, text=False);
# plt.plot([], [], label=r'M$_{true}$ = %.2e'%Mtrue + '\n' +
#                          r'M$_{mle}$ = %.2e'%Mmle + '\n' +
#                          r'J$_{min}$ = %.2f'%J_min + '\n' +
#                          r'$\rho_0$ = %.2e'%J_rho0 + '\n' +
#                          r'$r_0$ = %.2f'%J_r0)
# plt.ylim(-0.5,6);
# name = 'dsphsim_100_2p_Core_Plum_IS_wstaterr'
# plt.suptitle(name)
# plt.legend(numpoints=1, fontsize=12);
# #plt.savefig('../plots/%s.png'%name,format='png',dpi=300)
