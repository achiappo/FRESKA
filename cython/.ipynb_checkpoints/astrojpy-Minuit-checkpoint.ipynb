# %%
import numpy as np
from math import sqrt,log10
import pylab as plt
from scipy.interpolate import interp1d as interp
from scipy.optimize import brentq, minimize_scalar
from profiles import build_profile, build_kernel
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter

# %matplotlib inline

# %%
directory = '/home/andrea/Desktop/work/DWARF/dsphsim/'
rh = 0.04
D = 39.81
theta = 2*rh/D
dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf}

# %% [markdown]
# ## True values

# %%
dm_true = build_profile('NFW')
rvmax = 0.757
vmax = 10.4
rs = rvmax/2.163
rhos = 4.625 * (vmax/rs)**2 / (4*np.pi*4.302e-6)
dm_true.r0 = rs
dm_true.rho0 = rhos
Jtrue = log10(dm_true.Jfactor(**dwarf_props))
print 'rs = %.2f, rhos = %.2e, J = %g'%(rs,rhos,Jtrue)
# Out:
# rs = 0.35, rhos = 7.55e+07, J = 16.724

# %%
dm = build_profile('NFW')
st = build_profile('plummer',rh=rh) # Plummer Stellar profile
kr = build_kernel('constbeta') # isotropic kernel
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

# %%
R, v = np.loadtxt(directory+'Ret2_data/dsph_002.txt',usecols=(5, 7),unpack=True)
vnan = np.isnan(v)
v = v[~vnan]
R = R[~vnan]
dv = np.zeros_like(v)

# %%
LL = GaussianLikelihood([R, v, dv, 0.], Sigma)
LL.set_free('dm_r0')
LL.set_free('dm_a')
LL.set_free('dm_b')
LL.set_free('dm_c')
LL.set_free('ker_beta')

# %%
LL.free_pars.keys()
# Out:
# ['dm_r0', 'J', 'dm_a', 'dm_b', 'dm_c', 'ker_beta']

# %%
J_array = np.linspace(15,18,20)
L_arr = np.empty([0])
parameters = np.array(LL.free_pars.keys())
for par in parameters:
    parname = par.split('_')[-1]
    exec( '%s_arr = np.zeros_like(J_array)'%parname)

# %%
for j,J in enumerate(J_array):
    M = MinuitFitter(LL)
    # J
    M.set_value('J',J)
    M.set_fixed('J')
    # r0
    M.set_value('dm_r0',rh*2.)
    M.set_error('dm_r0',0.01)
    # a
    M.set_value('dm_a',1.)
    M.set_error('dm_a',0.01)
    # b
    M.set_value('dm_b',3.)
    M.set_error('dm_b',0.01)
    # c
    M.set_value('dm_c',1.)
    M.set_error('dm_c',0.01)
    # beta
    M.set_value('ker_beta',0.)
    M.set_error('ker_beta',0.01)
    
    M.settings['print_level'] = 1
    M.set_minuit(**{'tol':1e7,'strategy':1})
    BF = M.migrad_min()
    
    valid = False
    while not valid:
        BF = M.migrad_min()
        valid = BF[0]['is_valid']
        if M.minuit.tol>1e10 and not valid: break
        M.minuit.tol *= 10
    else:
        L_arr = np.append(L_arr,BF[0]['fval'])
        for par in parameters:
            parname = par.split('_')[-1]
            indx = np.where( parameters==par )[0][0]
            exec( "{0}_arr[{1}] = BF[1][{2}]['value']".format(parname,j,indx))
# Out:
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:295: UserWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.080000
#            J = +15.000000
#         dm_a = +1.000000
#         dm_b = +3.000000
#         dm_c = +1.000000
#     ker_beta = -0.605961
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -nan
#            J = +15.000000
#         dm_a = -nan
#         dm_b = -nan
#         dm_c = -nan
#     ker_beta = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +nan
#            J = +15.000000
#         dm_a = +nan
#         dm_b = +nan
#         dm_c = +nan
#     ker_beta = +nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.113929
#            J = +15.000000
#         dm_a = +1.305177
#         dm_b = +0.904108
#         dm_c = +0.795328
#     ker_beta = -2.203530
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115626
#            J = +15.000000
#         dm_a = +1.320436
#         dm_b = +0.799313
#         dm_c = +0.785095
#     ker_beta = -2.293725
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115711
#            J = +15.000000
#         dm_a = +1.321199
#         dm_b = +0.794073
#         dm_c = +0.784583
#     ker_beta = -2.298235
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115715
#            J = +15.000000
#         dm_a = +1.321237
#         dm_b = +0.793811
#         dm_c = +0.784557
#     ker_beta = -2.298460
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115715
#            J = +15.000000
#         dm_a = +1.321239
#         dm_b = +0.793798
#         dm_c = +0.784556
#     ker_beta = -2.298471
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115715
#            J = +15.000000
#         dm_a = +1.321239
#         dm_b = +0.793798
#         dm_c = +0.784556
#     ker_beta = -2.298472
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.115715
#            J = +15.000000
#         dm_a = +1.321239
#         dm_b = +0.793797
#         dm_c = +0.784556
#     ker_beta = -2.298472
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1639.51520334</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 118</td>
#                 <td title="Number of call in last migrad">NCALLS = 118</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 215948.2046</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#wJRgUVwieH').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>6.267606e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>5.208283e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>3.059146e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>4.196722e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-3.996399e-01</td>
#                 <td>1.204372e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="wJRgUVwieH" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.000e-02 & 6.268e-03 &  &  &  &  & \\
# \hline
# 2 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.000e+00 & 5.208e-02 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 3.000e+00 & 3.059e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.000e+00 & 4.197e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -3.996e-01 & 1.204e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -3.973379
#            J = +15.000000
#         dm_a = -32.745251
#         dm_b = +202.120365
#         dm_c = +28.445679
#     ker_beta = -79.533388
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.176048
#            J = +15.000000
#         dm_a = -34.432514
#         dm_b = +212.076383
#         dm_c = +29.817963
#     ker_beta = -83.490076
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.186181
#            J = +15.000000
#         dm_a = -34.516877
#         dm_b = +212.574184
#         dm_c = +29.886577
#     ker_beta = -83.687910
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.186688
#            J = +15.000000
#         dm_a = -34.521095
#         dm_b = +212.599074
#         dm_c = +29.890008
#     ker_beta = -83.697802
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.186713
#            J = +15.000000
#         dm_a = -34.521306
#         dm_b = +212.600318
#         dm_c = +29.890179
#     ker_beta = -83.698296
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.186715
#            J = +15.000000
#         dm_a = -34.521317
#         dm_b = +212.600381
#         dm_c = +29.890188
#     ker_beta = -83.698321
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -4.186715
#            J = +15.000000
#         dm_a = -34.521317
#         dm_b = +212.600384
#         dm_c = +29.890188
#     ker_beta = -83.698322
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1639.51520334</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 152</td>
#                 <td title="Number of call in last migrad">NCALLS = 21</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 215947.096165</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#lWAQMPaAxV').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>6.267606e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>5.208283e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>3.059146e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>4.196722e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-3.996399e-01</td>
#                 <td>1.204372e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="lWAQMPaAxV" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.000e-02 & 6.268e-03 &  &  &  &  & \\
# \hline
# 2 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.000e+00 & 5.208e-02 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 3.000e+00 & 3.059e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.000e+00 & 4.197e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -3.996e-01 & 1.204e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.080000
#            J = +15.157895
#         dm_a = +1.000000
#         dm_b = +3.000000
#         dm_c = +1.000000
#     ker_beta = -0.641687
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -nan
#            J = +15.157895
#         dm_a = -nan
#         dm_b = -nan
#         dm_c = -nan
#     ker_beta = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +nan
#            J = +15.157895
#         dm_a = +nan
#         dm_b = +nan
#         dm_c = +nan
#     ker_beta = +nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.111376
#            J = +15.157895
#         dm_a = +1.281209
#         dm_b = +1.365568
#         dm_c = +0.823408
#     ker_beta = -0.681610
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.112944
#            J = +15.157895
#         dm_a = +1.295270
#         dm_b = +1.283846
#         dm_c = +0.814578
#     ker_beta = -0.694831
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.113023
#            J = +15.157895
#         dm_a = +1.295973
#         dm_b = +1.279760
#         dm_c = +0.814137
#     ker_beta = -0.695492
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.113027
#            J = +15.157895
#         dm_a = +1.296008
#         dm_b = +1.279556
#         dm_c = +0.814115
#     ker_beta = -0.695525
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.113027
#            J = +15.157895
#         dm_a = +1.296010
#         dm_b = +1.279545
#         dm_c = +0.814114
#     ker_beta = -0.695527
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1388.91291579</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 118</td>
#                 <td title="Number of call in last migrad">NCALLS = 118</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 18014.2682811</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#DPUsJDTguP').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>6.076214e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.515789e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>4.863567e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>5.669711e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>5.927809e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-4.171823e-01</td>
#                 <td>7.066717e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="DPUsJDTguP" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.000e-02 & 6.076e-03 &  &  &  &  & \\
# \hline
# 2 & J & 1.516e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.000e+00 & 4.864e-02 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 3.000e+00 & 5.670e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.000e+00 & 5.928e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -4.172e-01 & 7.067e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -0.984177
#            J = +15.157895
#         dm_a = -7.549734
#         dm_b = +108.884891
#         dm_c = +12.096016
#     ker_beta = -13.795620
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.037385
#            J = +15.157895
#         dm_a = -7.977221
#         dm_b = +114.179135
#         dm_c = +12.650817
#     ker_beta = -14.464541
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.040046
#            J = +15.157895
#         dm_a = -7.998595
#         dm_b = +114.443847
#         dm_c = +12.678557
#     ker_beta = -14.497988
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.040179
#            J = +15.157895
#         dm_a = -7.999664
#         dm_b = +114.457083
#         dm_c = +12.679944
#     ker_beta = -14.499660
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.040186
#            J = +15.157895
#         dm_a = -7.999717
#         dm_b = +114.457745
#         dm_c = +12.680013
#     ker_beta = -14.499743
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.040186
#            J = +15.157895
#         dm_a = -7.999720
#         dm_b = +114.457778
#         dm_c = +12.680016
#     ker_beta = -14.499748
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -1.040186
#            J = +15.157895
#         dm_a = -7.999720
#         dm_b = +114.457780
#         dm_c = +12.680017
#     ker_beta = -14.499748
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1388.91291579</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 152</td>
#                 <td title="Number of call in last migrad">NCALLS = 21</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 17994.0553367</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#lFWFlkhAnW').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>6.076214e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.515789e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>4.863567e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>5.669711e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>5.927809e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-4.171823e-01</td>
#                 <td>7.066717e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="lFWFlkhAnW" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.000e-02 & 6.076e-03 &  &  &  &  & \\
# \hline
# 2 & J & 1.516e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.000e+00 & 4.864e-02 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 3.000e+00 & 5.670e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.000e+00 & 5.928e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -4.172e-01 & 7.067e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.080000
#            J = +15.315789
#         dm_a = +1.000000
#         dm_b = +3.000000
#         dm_c = +1.000000
#     ker_beta = -0.701839
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -nan
#            J = +15.315789
#         dm_a = -nan
#         dm_b = -nan
#         dm_c = -nan
#     ker_beta = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +nan
#            J = +15.315789
#         dm_a = +nan
#         dm_b = +nan
#         dm_c = +nan
#     ker_beta = +nan
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1180.03541998</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 125</td>
#                 <td title="Number of call in last migrad">NCALLS = 125</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 714.335396108</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#mCkvSSauqR').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.496324e-02</td>
#                 <td>1.654923e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.531579e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.048089e+00</td>
#                 <td>4.829448e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>2.864956e+00</td>
#                 <td>2.053434e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>9.749769e-01</td>
#                 <td>6.082691e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-4.551049e-01</td>
#                 <td>9.429461e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="mCkvSSauqR" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.496e-02 & 1.655e-01 &  &  &  &  & \\
# \hline
# 2 & J & 1.532e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.048e+00 & 4.829e-01 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 2.865e+00 & 2.053e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 9.750e-01 & 6.083e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -4.551e-01 & 9.429e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.207492
#            J = +15.315789
#         dm_a = +19.011703
#         dm_b = +0.493785
#         dm_c = -1.207440
#     ker_beta = -0.796207
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.522115
#            J = +15.315789
#         dm_a = +19.909883
#         dm_b = +0.375227
#         dm_c = -1.316561
#     ker_beta = -0.813262
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.537846
#            J = +15.315789
#         dm_a = +19.954792
#         dm_b = +0.369299
#         dm_c = -1.322017
#     ker_beta = -0.814115
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.538633
#            J = +15.315789
#         dm_a = +19.957038
#         dm_b = +0.369002
#         dm_c = -1.322289
#     ker_beta = -0.814158
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.538672
#            J = +15.315789
#         dm_a = +19.957150
#         dm_b = +0.368987
#         dm_c = -1.322303
#     ker_beta = -0.814160
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -6.538674
#            J = +15.315789
#         dm_a = +19.957156
#         dm_b = +0.368987
#         dm_c = -1.322304
#     ker_beta = -0.814160
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1180.03541998</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 155</td>
#                 <td title="Number of call in last migrad">NCALLS = 17</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 730.228750662</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#SbnqzqJVzw').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>8.496324e-02</td>
#                 <td>1.654923e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.531579e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>1.048089e+00</td>
#                 <td>4.829448e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>2.864956e+00</td>
#                 <td>2.053434e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>9.749769e-01</td>
#                 <td>6.082691e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-4.551049e-01</td>
#                 <td>9.429461e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="SbnqzqJVzw" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 8.496e-02 & 1.655e-01 &  &  &  &  & \\
# \hline
# 2 & J & 1.532e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 1.048e+00 & 4.829e-01 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 2.865e+00 & 2.053e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 9.750e-01 & 6.083e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -4.551e-01 & 9.429e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.113067
#            J = +15.473684
#         dm_a = +1.298822
#         dm_b = +1.107476
#         dm_c = +0.808703
#     ker_beta = -3.117674
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.114720
#            J = +15.473684
#         dm_a = +1.313763
#         dm_b = +1.012850
#         dm_c = +0.799138
#     ker_beta = -3.256588
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.114803
#            J = +15.473684
#         dm_a = +1.314510
#         dm_b = +1.008119
#         dm_c = +0.798660
#     ker_beta = -3.263533
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.114807
#            J = +15.473684
#         dm_a = +1.314547
#         dm_b = +1.007882
#         dm_c = +0.798636
#     ker_beta = -3.263881
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.114807
#            J = +15.473684
#         dm_a = +1.314549
#         dm_b = +1.007870
#         dm_c = +0.798635
#     ker_beta = -3.263898
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +0.114807
#            J = +15.473684
#         dm_a = +1.314549
#         dm_b = +1.007870
# ...
#                 <td title="Number of call in last migrad">NCALLS = 21</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 12.1554629201</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#GRsDRMUwAL').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>4.749395e-02</td>
#                 <td>1.867708e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.752632e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>8.576515e-01</td>
#                 <td>2.425171e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>2.921213e+00</td>
#                 <td>3.572250e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.030345e+00</td>
#                 <td>1.770700e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-1.427492e-01</td>
#                 <td>1.923140e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="GRsDRMUwAL" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 4.749e-02 & 1.868e-02 &  &  &  &  & \\
# \hline
# 2 & J & 1.753e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 8.577e-01 & 2.425e-01 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 2.921e+00 & 3.572e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.030e+00 & 1.771e-01 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -1.427e-01 & 1.923e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = -0.015454
#            J = +17.684211
#         dm_a = +1.000000
#         dm_b = +3.000000
#         dm_c = +1.000000
#     ker_beta = +0.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#        dm_r0 = +nan
#            J = +17.684211
#         dm_a = +nan
#         dm_b = +nan
#         dm_c = +nan
#     ker_beta = +nan
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1124.37051219</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 90</td>
#                 <td title="Number of call in last migrad">NCALLS = 90</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 113.869779164</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5e+12</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#MosmbDsBEG').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_r0</td>
#                 <td>4.724109e-02</td>
#                 <td>3.175871e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>J</td>
#                 <td>1.768421e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>dm_a</td>
#                 <td>9.701839e-01</td>
#                 <td>7.965313e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_b</td>
#                 <td>3.012344e+00</td>
#                 <td>1.759516e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_c</td>
#                 <td>1.004632e+00</td>
#                 <td>9.958100e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>6</td>
#                 <td>ker_beta</td>
#                 <td>-7.332624e-04</td>
#                 <td>2.938367e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="MosmbDsBEG" style="display:none;">
#             <textarea rows="18" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{r0}$ & 4.724e-02 & 3.176e-02 &  &  &  &  & \\
# \hline
# 2 & J & 1.768e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 3 & $dm_{a}$ & 9.702e-01 & 7.965e-01 &  &  &  &  & \\
# \hline
# 4 & $dm_{b}$ & 3.012e+00 & 1.760e-01 &  &  &  &  & \\
# \hline
# 5 & $dm_{c}$ & 1.005e+00 & 9.958e-02 &  &  &  &  & \\
# \hline
# 6 & $ker_{\beta}$ & -7.333e-04 & 2.938e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: Exception Occured
# fcn is called with following arguments:
#        dm_r0 = +0.047241
#            J = +17.684211
#         dm_a = +0.970184
#         dm_b = +3.008269
#         dm_c = +1.004632
#     ker_beta = -0.000733
#
#   return self.minuit.migrad(**kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-ebe32ce84d8c> in <module>()
#      26     valid = False
#      27     while not valid:
# ---> 28         BF = M.migrad_min()
#      29         valid = BF[0]['is_valid']
#      30         if M.minuit.tol>1e10 and not valid: break
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in migrad_min(self, **kwargs)
#      79         def migrad_min(self, **kwargs):
#      80                 self.migrad_args = kwargs
# ---> 81                 return self.minuit.migrad(**kwargs)
#      82
#      83         def minos_profile(self, var, **kwargs):
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.migrad (iminuit/_libiminuit.cpp:5250)()
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in <lambda>(dm_r0, J, dm_a, dm_b, dm_c, ker_beta)
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in __call__(self, *par_array)
#      42                                 for i,key in enumerate(self.free_pars.keys()):
#      43                                         self.sigma.setparams(key, par_array[i])
# ---> 44                                 S = self.compute()
#      45                                 #self._store(S, *par_array)
#      46                         return S
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in compute(self)
#      59         #in case of an array of Js, one should write another scan function
#      60         #so it might be that here only the R parallelization is in order
# ---> 61         S = dv**2 + self.sigma.compute(R) #this is an array like R array
#      62         res = np.log(S) + ((v-vsys)**2)/S
#      63         return res.sum() / 2.
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in compute(self, R)
#      63                 sigma2 = np.zeros_like(R)
#      64                 for i,rr in enumerate(R):
# ---> 65                         integral = quad(self.integrand, rr, np.inf, args=(rr,))[0]
#      66                         I_of_R = self.stellar.surface_brightness(rr)
#      67                         sigma2[i] = integral / I_of_R / Jred
#
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     252         args = (args,)
#     253     if (weight is None):
# --> 254         retval = _quad(func,a,b,args,full_output,epsabs,epsrel,limit,points)
#     255     else:
#     256         retval = _quad_weight(func,a,b,args,full_output,epsabs,epsrel,limlst,limit,maxp1,weight,wvar,wopts)
#
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     319             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     320         else:
# --> 321             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     322     else:
#     323         if infbounds != 0:
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in integrand(self, s, R, **kwargs)
#      48         r0 = kwargs['r0'] if 'r0' in kwargs else self.dm.r0
#      49         rh = kwargs['rh'] if 'rh' in kwargs else self.stellar.rh
# ---> 50         val = self.stellar.density(s/rh) * self.dm.mass(s/r0) * self.kernel(s, R) / s
#      51         return val
#      52
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/profiles.pyc in mass(self, x)
#     180
#     181         def mass(self, x):
# --> 182                 a, b, c = self.a, self.b, self.c
#     183                 return cyfuncs.mass_func(x, a, b, c)
#     184
#
# KeyboardInterrupt:

# %%
interp_L = interp(J_arr, L_arr-L_arr.min())
for par in parameters:
    parname = par.split('_')[-1]
    exec( 'interp_{p} = interp(J_arr, {p}_arr)'.format(p=parname))

# %%
eval_Like_J = np.linspace(J_arr.min(), J_arr.max(), 1e3)
min_Like_J = interp_L(eval_Like_J).min()
Jmin = eval_Like_J[ np.where( interp_L(eval_Like_J) == min_Like_J )[0][0] ]
J_plt = np.linspace(J_arr.min(),J_arr.max())

# %% [raw]
# sortr = np.argsort(r_arr)
# interp_rL = interp(r_arr[sortr], L_arr[sortr]-L_arr.min())
# r_plt = np.linspace(r_arr.min(), r_arr.max())

# %% [raw]
# for i in range(1,r_arr.size):
#     if J_new[i-1] < Jmin < J_new[i]:
#         print r_arr[i-1], Jr, r_arr[i]
#         ibef = i-1
#         iaft = i

# %% [raw]
# plt.plot(r_arr, L_arr-L_arr.min());
# plt.plot(Jr, 0, 'r*', markersize=10, label=r'MLE: $r_s$ = %.2f'%Jr)
# plt.plot(rs, 0, 'b*', markersize=10, label='True : $r_s$ = %.2f'%rs);
# plt.plot(r_arr, L_arr-L_arr.min(), 'k|', markersize=20, label='interpolated points')
# plt.ylabel(r'$\mathcal{L(J)}$', fontsize=16)
# plt.xlabel(r'$r_s$', fontsize=16)
# plt.hlines(0, r_arr.min(), r_arr.max(), linestyle='--', color='k')
# plt.hlines(0.5, 0, r_arr.max(), linestyle='--', color='r', label=r'$1-\sigma$')
# plt.hlines(2.0, 0, r_arr.max(), linestyle='--', color='g', label=r'$2-\sigma$')
# plt.hlines(4.5, 0, r_arr.max(), linestyle='--', color='c', label=r'$3-\sigma$')
# plt.xlim(0,1);
# plt.ylim(-0.5,10);
# plt.legend(numpoints=1).get_frame().set_facecolor('w');
# #plt.savefig('results/Like_r.png', format='png', dpi=300);

# %% [raw]
# plt.plot(J_plt, interp_r(J_plt))
# plt.plot(Jmin, Jr, 'r*', markersize=10, label=r'MLE: $\mathcal{J}$ = %.2f, $r_s$ = %.2f'%(Jmin, Jr))
# plt.plot(Jtrue, rs, 'b*', markersize=10, label='True : $\mathcal{J}$ = %.2f, $r_s$ = %.2f'%(Jtrue, rs))
# J1L = Jmin - 0.11
# r1L = interp_r(J1L)
# plt.plot(J1L, r1L, 'y*', markersize=10, label=r'$r_s$ = %.2f : $r_s$ at $\mathcal{J} - 1\sigma$'%r1L)
# plt.plot(J_new, r_arr, 'k|', markersize=20, label='interpolated points')
# plt.xlabel(r'$\mathcal{J}$', fontsize=16)
# plt.ylabel(r'$r_s$', fontsize=16)
# plt.legend(numpoints=1)
# plt.ylim(0,0.5);
# plt.xlim(16.5,17.5);
# #plt.savefig('results/J_r.png', format='png', dpi=300);

# %%
Jr = float(interp_r0(Jmin))
Ja = float(interp_a(Jmin))
Jb = float(interp_b(Jmin))
Jc = float(interp_c(Jmin))
Jbeta = float(interp_beta(Jmin))

# %%
dm.r0 = Jr
dm.a = Ja
dm.b = Jb
dm.c = Jc
minrho = lambda rho : abs(Jmin - np.log10( dm.Jfactor(**dwarf_props) ) - 2*rho)
Jrho = float(10**minimize_scalar(minrho).x)

# %%
print 'r = %.2f, rho = %.2e, a = %.2f, b = %.2f, c = %.2f'%(Jr, Jrho, Ja, Jb, Jc)
#print 'r = %.2f, rho = %.2e , c = %.2f'%(Jr, Jrho ,Jc)

# %%
for i,c in enumerate([0.5,2.0,4.5]):
    exec('J%ssL = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, J_arr.min(), Jmin) - Jmin))
    exec('J%ssR = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, Jmin, J_arr.max()) - Jmin))

# %%
plt.plot(J_plt, interp_L(J_plt))
plt.hlines(0, J_plt.min(), J_plt.max(), linestyles='dashed')
plt.plot(Jmin, 0, 'b^', markersize=10, label=r'$\mathcal{J}_{MLE}$ = %.2f'%Jmin)
plt.plot(16.72, 0, 'rd', markersize=6, label=r'$\mathcal{J}_{TRUE}$ = 16.72')
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    JL, JR = eval('J%ssL'%str(i+1)), eval('J%ssR'%str(i+1))
    plt.hlines(h, J_plt.min(), J_plt.max(), linestyles='dashed', colors=c,
              label=r'$%i-\sigma$'%(i+1)+'\t'+'[%2s,%2s]'%(str(JL),str(JR)))
plt.legend(numpoints=1,fontsize=14).get_frame().set_facecolor('w')
plt.text(16.3, 7,'a = %.2f (1)'%Ja +'\n'+
                 'b = %.2f (3)'%Jb +'\n'+
                 'c = %.2f (1)'%Jc +'\n'+
                 r'$r_s$ = %.2f (0.35)'%Jr +'\n'+
                 r'$\rho_s$ = %.2e'%Jrho +'\n     (7.55e+07)')

plt.ylim(-0.5,12);
#plt.xlim(16.3,17.5);
#plt.savefig('results/LikeJ_rabc.png',format='png',dpi=300);
