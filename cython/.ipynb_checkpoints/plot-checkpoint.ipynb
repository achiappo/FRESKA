# %%
import os
import yaml
import numpy as np
from math import sqrt,log10
import pylab as plt
from scipy.optimize import brentq
from scipy.interpolate import interp1d as interp
from scipy.interpolate import UnivariateSpline as spline

# %matplotlib inline

# %% [raw]
# J_arr, L_arr = np.load('results/LikeJ_N1a0.5b2.0c0.0r0.15.npy')

# %% [raw]
# params = np.load('results/params_16000_test.npy')

# %% [raw]
# L, a, b, c, r = params
# Lnan = np.logical_or(np.logical_or(np.isnan(L), np.isinf(L)), L==0.)
# L = L[~Lnan]
# a = a[~Lnan]
# b = b[~Lnan]
# c = c[~Lnan]
# r = r[~Lnan]

# %% [raw]
# indLmin = np.where( L==min(L) )[0]
# Lmin = L[indLmin][0]

# %% [raw]
# cutL = L < int(Lmin)+100
# for par in ['L', 'a', 'b', 'c', 'r']:
#     exec( "{p} = {p}[cutL]".format(p=par) )

# %% [raw]
# sortL = np.argsort(L)#[::-1]
# for par in ['L', 'a', 'b', 'c', 'r']:
#     exec( "{p} = {p}[sortL]".format(p=par) )

# %% [raw]
# cm = plt.cm.get_cmap('RdYlBu')
# pairs = [('a','b'), ('a','c'), ('a','r'), ('b','c'), ('b','r'), ('c','r')]
# fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(15,7))
# for dat, ax in zip(pairs, axes.flat):
#     # The vmin and vmax arguments specify the color limits
#     exec('xvalues = {}'.format(dat[0]) )
#     exec('yvalues = {}'.format(dat[1]) )
#     sc = ax.scatter( xvalues, yvalues, c=L-min(L), cmap=cm, lw=0 );
#     ax.set_xlabel(dat[0], fontsize=12);
#     ax.set_ylabel(dat[1], fontsize=12);
#     cax = fig.add_axes([0.91, 0.1, 0.02, 0.8])
#     cbar = fig.colorbar(sc, cax=cax);
#     cbar.ax.set_ylabel('- log Likelihood', fontsize=14)
# #plt.savefig('results/Like_Mc_scatterplots.png', dpi=300, format='png');

# %% [raw]
# from mpl_toolkits.mplot3d import Axes3D
# cm = plt.cm.get_cmap('RdYlBu')
# pairs = [('a','b','c'), ('a','b','r'), ('b','c','r'), ('a','c','r')]
# fig = plt.figure(figsize=(15,7))
# for d,dat in enumerate(pairs):
#     # The vmin and vmax arguments specify the color limits
#     exec('xvalues = {}'.format(dat[0]) )
#     exec('yvalues = {}'.format(dat[1]) )
#     exec('zvalues = {}'.format(dat[2]) )
#     ax = fig.add_subplot(1, 4, d+1, projection='3d')
#     sc = ax.scatter( xvalues, yvalues, zvalues, c=L-min(L), cmap=cm, lw=0 );
#     ax.set_xlabel(dat[0], fontsize=12);
#     ax.set_ylabel(dat[1], fontsize=12);
#     ax.set_zlabel(dat[2], fontsize=12);
#     cax = fig.add_axes([0.91, 0.1, 0.02, 0.7])
#     cbar = fig.colorbar(sc, cax=cax);
#     cbar.ax.set_ylabel('- log Likelihood', fontsize=14)
# #plt.savefig('results/Like_Mc_3Dscatterplots.png', dpi=300, format='png');

# %% [raw]
# fig = plt.figure(figsize=(8,8))
# for i,par in enumerate(['a', 'b', 'c', 'r']):
#     ax = fig.add_subplot(2,2,i+1)
#     ax.plot( eval('{}'.format(par)), L, 'bo', alpha=0.2  );
#     exec( 'parmin = {}[indLmin]'.format(par) )
#     ax.plot( parmin, Lmin, 'r*', ms=10, label= '%s = %.2f'%(par, parmin) );
#     ax.set_xlabel(par);
#     if i%2 == 0:
#         ax.set_ylabel('-logLike')
#     ax.set_ylim(1e3, 2e3);
#     ax.legend(numpoints=1);
# plt.suptitle('J = 16 , %i points'%params[0].size, fontsize=14);
# #plt.savefig('results/Like_Mc10000_16.png', dpi=300, format='png');

# %%
params = np.load('results/params_Mc_100p10000s.npy')
for i,p in enumerate(['J', 'L', 'a', 'b', 'c', 'r']):
    exec('{} = np.empty([0])'.format(p))
    exec('{p} = np.append({p}, [params[n][i] for n in range(len(params))])'.format(p=p))

# %%
from sklearn.model_selection import LeaveOneOut

# %%
LOOCV = LeaveOneOut()

# %%
RSS = []
smoothing = range(10,101)
for s in smoothing:
    score = []
    for train, test in LOOCV.split(J, L):
        spline_L = spline(J[train], L[train], s=s)
        score.append( (J[test] - spline_L(J[test]))**2 )
    RSS.append( sum(score) )

# %%
def rss(s, X, Y):
    score = 0
    for train, test in LOOCV.split(X, Y):
        spl = spline(X[train], Y[train], s=s)
        score += (X[test] - spl(X[test]))**2
    return score

# %%
from scipy.optimize import fmin

# %%
res = fmin(rss, x0=70, args=(J,L))
# Out:
# Optimization terminated successfully.
#          Current function value: 139221406.787729
#          Iterations: 33
#          Function evaluations: 69

# %%
res
# Out:
# array([ 75.29048491])

# %%
mins = np.where( RSS==min(RSS) )[0][0]

# %%
plt.plot(smoothing, RSS);
plt.plot(smoothing[mins], RSS[mins], 'r*', ms=8);

# %%
#s = smoothing[mins]
s = res
linear_L = interp(J, L)
spline_L = spline(J, L, s=s)

eval_Like_J = np.linspace(min(J), max(J), 1e3)
min_Like_J = spline_L(eval_Like_J).min()
Jmin = eval_Like_J[ np.where( spline_L(eval_Like_J) == min_Like_J )[0][0] ]
J_plt = np.linspace(min(J),max(J))

# %%
for par in ['a', 'b', 'c', 'r']:
    exec( 'pars = fmin(rss, x0=70, args=(J,{}))'.format(par))
    exec( 'spl_{par} = spline(J, {par}, s=pars)'.format(par=par))
    exec( 'J{0} = float(spl_{0}(Jmin))'.format(par) )

print 'r = %.2f, a = %.2f, b = %.2f, c = %.2f'%(Jr, Ja, Jb, Jc)
# Out:
# Optimization terminated successfully.
#          Current function value: 24332.782089
#          Iterations: 28
#          Function evaluations: 57
# [ 69.08760262]
# Optimization terminated successfully.
#          Current function value: 21183.465260
#          Iterations: 20
#          Function evaluations: 46
# [ 73.04060364]
# Optimization terminated successfully.
#          Current function value: 25521.203850
#          Iterations: 17
#          Function evaluations: 50
# [ 70.]
# Optimization terminated successfully.
#          Current function value: 23714.747117
#          Iterations: 27
#          Function evaluations: 58
# [ 75.16463089]
# r = 3.34, a = 0.46, b = 3.82, c = 0.75

# %%
fig = plt.figure(figsize=(8,8))
for i,p in enumerate(['a', 'b', 'c', 'r']):
    ax = fig.add_subplot(2,2,i+1)
    ax.plot(J, eval( '{}'.format(p) ) );
    ax.plot(J, eval( 'spl_{}(J)'.format(p) ) );
    ax.set_title(p, fontsize=14);

# %% [raw]
# fig = plt.figure(figsize=(8,8))
# for i,par in enumerate(['a', 'b', 'c', 'r']):
#     #exec( 'interp_L{0} = spline({0}, L, s=500)'.format(par))
#     ax = fig.add_subplot(2,2,i+1)
#     #ax.plot(eval('{}'.format(par)), eval( 'interp_L{0}({0})'.format(par) ) );
#     ax.plot(eval('{}'.format(par)), L, 'bo', alpha=0.6  );
#     ax.plot(eval('J{}'.format(par)), min(L), 'r*', ms=10 );
#     ax.set_xlabel(par);
# #plt.savefig('results/Like_Mc_abcr_100p_dots.png', dpi=300, format='png');

# %%
for i,c in enumerate([0.5,2.0,4.5]):
    exec('J%ssL = %.2f'%(i+1, brentq(lambda j : spline_L(j)-spline_L(J).min()-c, min(J), Jmin) - Jmin))
    exec('J%ssR = %.2f'%(i+1, brentq(lambda j : spline_L(j)-spline_L(J).min()-c, Jmin, max(J)) - Jmin))

# %%
lin = linear_L(J)
spl = spline_L(J)
#plt.plot(J, L-L.min(), 'ro', ms=5);
#plt.plot(J, lin-lin.min(), 'bo', ms=5);
plt.plot(J, spl-spl.min(), 'g', lw=2);

plt.hlines(0, min(J), max(J), linestyles='dashed')
plt.plot(Jmin, 0, 'b^', markersize=10, label=r'$\mathcal{J}_{MLE}$ = %.2f'%Jmin)
plt.plot(16.72, 0, 'rd', markersize=6, label=r'$\mathcal{J}_{TRUE}$ = 16.72')
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    JL, JR = eval('J%ssL'%str(i+1)), eval('J%ssR'%str(i+1))
    plt.hlines(h, J_plt.min(), J_plt.max(), linestyles='dashed', colors=c,
              label=r'$%i-\sigma$'%(i+1)+'\t'+'[%2s,%2s]'%(str(JL),str(JR)))
plt.legend(numpoints=1,fontsize=14).get_frame().set_facecolor('w')
plt.text(15.5, 8,'a = %.2f (1)'%Ja +'\n'+
                 'b = %.2f (3)'%Jb +'\n'+
                 'c = %.2f (1)'%Jc +'\n'+
                 r'$r_s$ = %.2f (0.35)'%Jr)

plt.ylim(-0.5,12);
plt.suptitle("Mcmc, 100 Js, 10000 Mc points, s=%i"%s);
#plt.savefig('results/LikeJ_Mc10000_rabc_100p_CVs.png',format='png',dpi=300);

# %% [raw]
# paramfiles = ['results_N%ia0.5b2.0c0.0r0.15.yaml'%i for i in range(1,101)]
# LikeJfiles = ['LikeJ_N%ia0.5b2.0c0.0r0.15.npy'%i for i in range(1,101)]

# %% [raw]
# params = {'Jmin':16.72, 'a':1, 'b':3, 'c':1, 'r':0.35}
# for p in params.keys():
#     exec( '%s = np.empty([0])'%p )

# %% [raw]
# for f in paramfiles:
#     results = yaml.load(open('results/'+f))
#     for p in params.keys():
#         exec( "{p} = np.append({p}, results['{p}'])".format(p=p) )

# %% [raw]
# for p,v in sorted(params.items()):
#         exec( "{p}mean, {p}mrms = {p}.mean(), {p}.std()/sqrt({p}.size)".format(p=p) )

# %% [raw]
# print '%4s %6s %8s %12s'%('param','true val', 'mean', 'mean_rms')
# for p,v in sorted(params.items()):
#         print '%4s'%p, '%8g'%v, '%10.2f %10.2f'%eval( '{p}mean, {p}mrms'.format(p=p) )

# %% [raw]
# plt.hist(Jmin, bins=20);
# plt.vlines(16.72, 0, 30);

# %% [raw]
# fig = plt.figure(figsize=(20,20))
# for i,f in enumerate(LikeJfiles):
#     J,L = np.load('results/'+f)
#     ax = fig.add_subplot(10,10,i)
#     ax.plot(J,L)
#     ax.plot(Jmin[i],0,'c^',markersize=10)
#     ax.plot(16.72,0,'r*',markersize=10)
#     for tick in ax.xaxis.get_major_ticks(): tick.label.set_fontsize(8)
#     for tick in ax.yaxis.get_major_ticks(): tick.label.set_fontsize(8)
#     ax.hlines(0.,min(J),max(J),linestyles='dashed')
#     ax.hlines(.5,min(J),max(J),colors=('r'),linestyles='dashed')
#     ax.hlines(2.,min(J),max(J),colors=('g'),linestyles='dashed')
#     ax.hlines(4.,min(J),max(J),colors=('c'),linestyles='dashed')
#     ax.set_ylim(-0.5,12)
#     ax.set_xlim(min(J),max(J))
# plt.suptitle('a = 2. (1) , b = 3.5 (3) , c = 1.5 (1) , r = 0.50 (0.35)');
# #plt.savefig('results/LikeJs_a2.0b3.5c1.5r0.50.png', dpi=300, format='png');

# %% [raw]
# Jmin = np.array( Jmin )

# %% [raw]
# from cyfuncs import mass_func as M

# %% [raw]
# a, b, c = 1., 3., 0.

# %% [raw]
# r_arr = np.logspace(0,3)
# M_arr = [M(r,1,3,-1) for r in r_arr]
# plt.plot(r_arr,M_arr);

# %% [raw]
# B = []
# N = int(10**1)
# R = range(5,10)+range(10,100,10)+range(100,1000,100)
# for r in [1000]:
#     c_arr = np.arange(0,3,0.001)
#     M_arr = np.asarray([M(r, a, b, c) for c in c_arr])
#     print r, c_arr[ np.where( M_arr>0 )[0] ]
#     #B.append( b_arr[ np.where( np.isnan(M_arr) )[0][0] ] )
#     plt.plot(c_arr, M_arr, label=r);
# #plt.legend();

# %% [raw]
# mcmc = np.load('results/params_Mc_100p110000s.npy')

# %% [raw]
# for i,p in enumerate(['J', 'L', 'a', 'b', 'c', 'r']):
#     exec( '{} = np.array( [mcmc[n][i] for n in range(len(mcmc))] )'.format(p) )

# %%
J, L, a, b, c, r = np.load('results/LikeJ1.npy')

# %%
s = 5000
linear_L = interp(J, L)
spline_L = spline(J, L, s=s)

eval_Like_J = np.linspace(J.min(), J.max(), 1e3)
min_Like_J = spline_L(eval_Like_J).min()
Jmin = eval_Like_J[ np.where( spline_L(eval_Like_J) == min_Like_J )[0][0] ]
J_plt = np.linspace(J.min(),J.max())

# %%
for par in ['a', 'b', 'c', 'r']:
    exec( 'interp_{0} = spline(J, {0}, s=s)'.format(par))
    exec( 'J{0} = float(interp_{0}(Jmin))'.format(par) )

print 'r = %.2f, a = %.2f, b = %.2f, c = %.2f'%(Jr, Ja, Jb, Jc)
# Out:
# r = 0.34, a = 1.12, b = 2.48, c = 1.00

# %% [raw]
# fig = plt.figure(figsize=(8,8))
# for i,p in enumerate(['a', 'b', 'c', 'r']):
#     ax = fig.add_subplot(2,2,i+1)
#     ax.plot(J, eval( '{}'.format(p) ) );
#     ax.plot(J, eval( 'interp_{}(J)'.format(p) ) );
#     ax.set_title(p, fontsize=14);

# %% [raw]
# lin = linear_L(J)
# spl = spline_L(J)
# plt.plot(J, L-L.min(), 'ro', ms=5);
# #plt.plot(J, lin-lin.min(), 'b', label='linear interpolation');
# #plt.plot(J, spl-spl.min(), 'g', label='smoothing spline', linewidth=2);
# plt.hlines(0, J.min(), J.max(), linestyles='dashed')
# plt.legend();
# plt.ylim(-5,50);
# #plt.savefig('results/LikeJ_Mc.png',format='png',dpi=300);

# %%
for i,c in enumerate([0.5,2.0,4.5]):
    exec('J%ssL = %.2f'%(i+1, brentq(lambda j : spline_L(j)-spline_L(J).min()-c, J.min(), Jmin) - Jmin))
    exec('J%ssR = %.2f'%(i+1, brentq(lambda j : spline_L(j)-spline_L(J).min()-c, Jmin, J.max()) - Jmin))

# %%
lin = linear_L(J)
spl = spline_L(J)
plt.plot(J, L-L.min(), 'rd', ms=5);
#plt.plot(J, lin-lin.min(), 'b');
plt.plot(J, spl-spl.min(), 'g');

plt.hlines(0, J.min(), J.max(), linestyles='dashed')
plt.plot(Jmin, 0, 'b^', markersize=10, label=r'$\mathcal{J}_{MLE}$ = %.2f'%Jmin)
plt.plot(16.72, 0, 'rd', markersize=6, label=r'$\mathcal{J}_{TRUE}$ = 16.72')
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    JL, JR = eval('J%ssL'%str(i+1)), eval('J%ssR'%str(i+1))
    plt.hlines(h, J_plt.min(), J_plt.max(), linestyles='dashed', colors=c,
              label=r'$%i-\sigma$'%(i+1)+'\t'+'[%2s,%2s]'%(str(JL),str(JR)))
plt.legend(numpoints=1,fontsize=14).get_frame().set_facecolor('w')
plt.text(15.7, 8,'a = %.2f (1)'%Ja +'\n'+
                 'b = %.2f (3)'%Jb +'\n'+
                 'c = %.2f (1)'%Jc +'\n'+
                 r'$r_s$ = %.2f (0.35)'%Jr)

plt.ylim(-0.5,12);
plt.suptitle('Minuit, 100 Js, True initial guesses');
#plt.savefig('results/LikeJ_Min_rabc_100p_Tini.png',format='png',dpi=300);

# %%
params = np.load('results/params_Mc_100p10000s.npy')
for i,p in enumerate(['Jmc', 'Lmc']):
    exec('{} = np.empty([0])'.format(p))
    exec('{p} = np.append({p}, [params[n][i] for n in range(len(params))])'.format(p=p))

s = 100
spline_L = spline(Jmc, Lmc, s=s)

# %%
Jmi, Lmi = np.load('results/LikeJ.npy')[:2]

# %%
Jtrue, Ltrue = np.load('results/trueLikeJ.npy')

# %%
plt.plot(Jmc, Lmc-min(Lmc), 'bo', ms=5, label='MCMC');
plt.plot(Jmi, Lmi-min(Lmi), 'rd', ms=5, label='Minuit');
plt.plot(Jtrue, Ltrue-min(Ltrue), 'g', label='true Like J');

plt.hlines(0, min(J), max(J), linestyles='dashed')
plt.plot(16.72, 0, 'yd', markersize=8, label=r'$\mathcal{J}_{TRUE}$ = 16.72')

plt.legend(numpoints=1);
plt.ylim(-0.5,12);
#plt.savefig('results/LikeJ_comparison_wl.png',format='png',dpi=300);
