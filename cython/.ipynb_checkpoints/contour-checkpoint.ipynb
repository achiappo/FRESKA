# %%
import numpy as np
from math import sqrt,log10
import pylab as plt
from scipy.interpolate import interp1d as interp
from scipy.optimize import brentq, minimize_scalar
from profiles import build_profile, build_kernel
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter

# %matplotlib inline

# %%
directory = '/home/andrea/Desktop/work/DWARF/dsphsim/'
rh = 0.04
D = 39.81
theta = 2*rh/D
dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf}

# %% [markdown]
# ## True values

# %%
dm_true = build_profile('NFW')
rvmax = 0.757
vmax = 10.4
rs = rvmax/2.163
rhos = 4.625 * (vmax/rs)**2 / (4*np.pi*4.302e-6)
dm_true.r0 = rs
dm_true.rho0 = rhos
Jtrue = log10(dm_true.Jfactor(**dwarf_props))
print 'rs = %.2f, rhos = %.2e, J = %g'%(rs,rhos,Jtrue)
# Out:
# rs = 0.35, rhos = 7.55e+07, J = 16.724

# %%
dm = build_profile('NFW')
st = build_profile('plummer',rh=rh) # Plummer Stellar profile
kr = build_kernel('constbeta') # isotropic kernel
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

# %%
R, v = np.loadtxt(directory+'Ret2_data/dsph_002.txt',usecols=(5, 7),unpack=True)
vnan = np.isnan(v)
v = v[~vnan]
R = R[~vnan]
dv = np.zeros_like(v)

# %%
LL = GaussianLikelihood([R, v, dv, 0.], Sigma)
LL.set_free('dm_r0')
LL.set_free('dm_a')
LL.set_free('dm_b')
LL.set_free('dm_c')
#LL.set_free('ker_beta')

# %%
LL.free_pars.keys()
# Out:
# ['dm_a', 'dm_b', 'J', 'dm_c', 'dm_r0']

# %%
J_array = np.linspace(15,19,20)
L_arr = np.empty([0])
parameters = np.array(LL.free_pars.keys())
for par in parameters:
    parname = par.split('_')[-1]
    exec( '%s_arr = np.empty([0])'%parname)

# %%
for j,J in enumerate(J_array):
    M = MinuitFitter(LL)
    # J
    M.set_value('J',J)
    M.set_fixed('J')
    # r0
    M.set_value('dm_r0',rh*2.)
    M.set_error('dm_r0',0.01)
    # a
    M.set_value('dm_a',1.)
    M.set_error('dm_a',0.01)
    # b
    M.set_value('dm_b',3.)
    M.set_error('dm_b',0.01)
    # c
    M.set_value('dm_c',1.)
    M.set_error('dm_c',0.01)
    # beta
    #M.set_value('ker_beta',0.)
    #M.set_error('ker_beta',0.01)
    
    M.settings['print_level'] = 1
    M.set_minuit(**{'tol':1e4,'strategy':2})
    BF = M.migrad_min()
    
    valid = False
    while not valid:
        BF = M.migrad_min()
        valid = BF[0]['is_valid']
        if M.minuit.tol>1e8 and not valid: break
        M.minuit.tol *= 10
    else:
        L_arr = np.append(L_arr, BF[0]['fval'])
        for par in parameters:
            parname = par.split('_')[-1]
            indx = np.where( parameters==par )[0][0]
            exec( "{0}_arr = np.append({0}_arr, BF[1][{1}]['value'])".format(parname,indx))
# Out:
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.068629
#      dm_b = -50.742651
#         J = +15.000000
#      dm_c = +2.516630
#     dm_r0 = -0.725394
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.472060
#      dm_b = -53.429784
#         J = +15.000000
#      dm_c = +2.592462
#     dm_r0 = -0.765664
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.492232
#      dm_b = -53.564141
#         J = +15.000000
#      dm_c = +2.596253
#     dm_r0 = -0.767677
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493240
#      dm_b = -53.570858
#         J = +15.000000
#      dm_c = +2.596443
#     dm_r0 = -0.767778
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493291
#      dm_b = -53.571194
#         J = +15.000000
#      dm_c = +2.596452
#     dm_r0 = -0.767783
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493293
#      dm_b = -53.571211
#         J = +15.000000
#      dm_c = +2.596453
#     dm_r0 = -0.767783
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493293
#      dm_b = -53.571212
#         J = +15.000000
#      dm_c = +2.596453
#     dm_r0 = -0.767783
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3886.21216566</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 87</td>
#                 <td title="Number of call in last migrad">NCALLS = 74</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6831.1532931</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#sPyVqhVeRr').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>7.643576e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>4.995111e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>1.566549e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>7.648762e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="sPyVqhVeRr" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 7.644e-02 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 4.995e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 1.567e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 7.649e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.068620
#      dm_b = -50.742594
#         J = +15.000000
#      dm_c = +2.516628
#     dm_r0 = -0.725393
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.472051
#      dm_b = -53.429724
#         J = +15.000000
#      dm_c = +2.592460
#     dm_r0 = -0.765663
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.492222
#      dm_b = -53.564081
#         J = +15.000000
#      dm_c = +2.596251
#     dm_r0 = -0.767676
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493231
#      dm_b = -53.570798
#         J = +15.000000
#      dm_c = +2.596441
#     dm_r0 = -0.767777
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493281
#      dm_b = -53.571134
#         J = +15.000000
#      dm_c = +2.596450
#     dm_r0 = -0.767782
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493284
#      dm_b = -53.571151
#         J = +15.000000
#      dm_c = +2.596451
#     dm_r0 = -0.767782
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.493284
#      dm_b = -53.571152
#         J = +15.000000
#      dm_c = +2.596451
#     dm_r0 = -0.767782
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066943
#      dm_b = -50.728794
#         J = +15.000000
#      dm_c = +2.516194
#     dm_r0 = -0.725205
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470290
#      dm_b = -53.415234
#         J = +15.000000
#      dm_c = +2.592003
#     dm_r0 = -0.765466
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490458
#      dm_b = -53.549556
#         J = +15.000000
#      dm_c = +2.595794
#     dm_r0 = -0.767479
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491466
#      dm_b = -53.556272
#         J = +15.000000
#      dm_c = +2.595983
#     dm_r0 = -0.767579
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491516
#      dm_b = -53.556608
#         J = +15.000000
#      dm_c = +2.595993
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491519
#      dm_b = -53.556624
#         J = +15.000000
#      dm_c = +2.595993
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491519
#      dm_b = -53.556625
#         J = +15.000000
#      dm_c = +2.595993
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3886.21216566</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 153</td>
#                 <td title="Number of call in last migrad">NCALLS = 53</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6828.69456072</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#dwWsIvhYwL').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>7.643511e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>4.994821e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>1.566418e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>7.648507e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="dwWsIvhYwL" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 7.644e-02 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 4.995e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 1.566e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 7.649e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066934
#      dm_b = -50.728736
#         J = +15.000000
#      dm_c = +2.516192
#     dm_r0 = -0.725204
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470281
#      dm_b = -53.415173
#         J = +15.000000
#      dm_c = +2.592002
#     dm_r0 = -0.765465
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490448
#      dm_b = -53.549495
#         J = +15.000000
#      dm_c = +2.595792
#     dm_r0 = -0.767478
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491457
#      dm_b = -53.556211
#         J = +15.000000
#      dm_c = +2.595982
#     dm_r0 = -0.767578
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491507
#      dm_b = -53.556547
#         J = +15.000000
#      dm_c = +2.595991
#     dm_r0 = -0.767583
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491510
#      dm_b = -53.556564
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491510
#      dm_b = -53.556565
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066943
#      dm_b = -50.728804
#         J = +15.000000
#      dm_c = +2.516194
#     dm_r0 = -0.725205
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470291
#      dm_b = -53.415244
#         J = +15.000000
#      dm_c = +2.592004
#     dm_r0 = -0.765466
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490458
#      dm_b = -53.549566
#         J = +15.000000
#      dm_c = +2.595795
#     dm_r0 = -0.767479
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491466
#      dm_b = -53.556282
#         J = +15.000000
#      dm_c = +2.595984
#     dm_r0 = -0.767579
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491517
#      dm_b = -53.556618
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491519
#      dm_b = -53.556635
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3886.21216566</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 219</td>
#                 <td title="Number of call in last migrad">NCALLS = 53</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6828.69595159</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#ToTPEdaOkI').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>7.643510e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>4.994821e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>1.566419e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>7.648508e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="ToTPEdaOkI" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 7.644e-02 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 4.995e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 1.566e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 7.649e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066935
#      dm_b = -50.728746
#         J = +15.000000
#      dm_c = +2.516193
#     dm_r0 = -0.725205
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470281
#      dm_b = -53.415183
#         J = +15.000000
#      dm_c = +2.592002
#     dm_r0 = -0.765465
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490449
#      dm_b = -53.549505
#         J = +15.000000
#      dm_c = +2.595793
#     dm_r0 = -0.767478
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491457
#      dm_b = -53.556221
#         J = +15.000000
#      dm_c = +2.595982
#     dm_r0 = -0.767579
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491507
#      dm_b = -53.556557
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491510
#      dm_b = -53.556574
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491510
#      dm_b = -53.556575
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066945
#      dm_b = -50.728813
#         J = +15.000000
#      dm_c = +2.516194
#     dm_r0 = -0.725206
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470292
#      dm_b = -53.415253
#         J = +15.000000
#      dm_c = +2.592004
#     dm_r0 = -0.765466
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490459
#      dm_b = -53.549575
#         J = +15.000000
#      dm_c = +2.595795
#     dm_r0 = -0.767479
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491468
#      dm_b = -53.556291
#         J = +15.000000
#      dm_c = +2.595984
#     dm_r0 = -0.767580
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491518
#      dm_b = -53.556627
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491520
#      dm_b = -53.556644
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491521
#      dm_b = -53.556645
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3886.21216566</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 285</td>
#                 <td title="Number of call in last migrad">NCALLS = 53</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6828.69780811</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 50.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#MrAJNycwXn').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>7.643510e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>4.994821e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>1.566418e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>7.648508e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="MrAJNycwXn" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 7.644e-02 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 4.995e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 1.566e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 7.649e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066936
#      dm_b = -50.728755
#         J = +15.000000
#      dm_c = +2.516193
#     dm_r0 = -0.725205
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470282
#      dm_b = -53.415192
#         J = +15.000000
#      dm_c = +2.592002
#     dm_r0 = -0.765465
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490450
#      dm_b = -53.549514
#         J = +15.000000
#      dm_c = +2.595793
#     dm_r0 = -0.767478
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491458
#      dm_b = -53.556230
#         J = +15.000000
#      dm_c = +2.595982
#     dm_r0 = -0.767579
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491509
#      dm_b = -53.556566
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491511
#      dm_b = -53.556583
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491511
#      dm_b = -53.556584
#         J = +15.000000
#      dm_c = +2.595992
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066945
#      dm_b = -50.728812
#         J = +15.000000
#      dm_c = +2.516194
#     dm_r0 = -0.725206
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491521
#      dm_b = -53.556644
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 3886.21216566</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 351</td>
#                 <td title="Number of call in last migrad">NCALLS = 53</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 6828.69775328</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 500.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#XyDCZBZWCW').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>7.643510e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>4.994821e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>1.566418e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>7.648508e-03</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="XyDCZBZWCW" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 7.644e-02 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 4.995e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 1.566e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 7.649e-03 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066936
#      dm_b = -50.728754
#         J = +15.000000
#      dm_c = +2.516193
#     dm_r0 = -0.725205
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470283
#      dm_b = -53.415192
#         J = +15.000000
#      dm_c = +2.592002
#     dm_r0 = -0.765465
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.066943
#      dm_b = -50.728800
#         J = +15.000000
#      dm_c = +2.516194
#     dm_r0 = -0.725206
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.470290
#      dm_b = -53.415240
#         J = +15.000000
#      dm_c = +2.592004
#     dm_r0 = -0.765466
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.490457
#      dm_b = -53.549562
#         J = +15.000000
#      dm_c = +2.595795
#     dm_r0 = -0.767479
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491465
#      dm_b = -53.556279
#         J = +15.000000
#      dm_c = +2.595984
#     dm_r0 = -0.767579
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491516
#      dm_b = -53.556614
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767584
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491518
#      dm_b = -53.556631
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -7.491518
#      dm_b = -53.556632
#         J = +15.000000
#      dm_c = +2.595994
#     dm_r0 = -0.767585
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1303.73550093</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 1053</td>
#                 <td title="Number of call in last migrad">NCALLS = 702</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 13.1155770643</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5000.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#swpxiPTByP').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.338047e+00</td>
#                 <td>6.762855e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>7.819651e-01</td>
#                 <td>5.804409e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>7.683710e-01</td>
#                 <td>1.187351e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>1.158506e-01</td>
#                 <td>8.304797e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="swpxiPTByP" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.338e+00 & 6.763e-01 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 7.820e-01 & 5.804e-02 &  &  &  &  & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# ...
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#iUoHxXQwQM').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>1.471617e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>9.065598e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.605263e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>2.867139e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>1.497785e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="iUoHxXQwQM" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 1.472e-01 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 9.066e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.605e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 2.867e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 1.498e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.007499
#      dm_b = -28.653871
#         J = +16.052632
#      dm_c = +1.864190
#     dm_r0 = -0.428280
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.257874
#      dm_b = -30.236565
#         J = +16.052632
#      dm_c = +1.907399
#     dm_r0 = -0.453694
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.270393
#      dm_b = -30.315700
#         J = +16.052632
#      dm_c = +1.909560
#     dm_r0 = -0.454965
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271019
#      dm_b = -30.319656
#         J = +16.052632
#      dm_c = +1.909668
#     dm_r0 = -0.455028
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271050
#      dm_b = -30.319854
#         J = +16.052632
#      dm_c = +1.909673
#     dm_r0 = -0.455031
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271052
#      dm_b = -30.319864
#         J = +16.052632
#      dm_c = +1.909673
#     dm_r0 = -0.455032
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271052
#      dm_b = -30.319865
#         J = +16.052632
#      dm_c = +1.909673
#     dm_r0 = -0.455032
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.007513
#      dm_b = -28.653956
#         J = +16.052632
#      dm_c = +1.864193
#     dm_r0 = -0.428281
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.257889
#      dm_b = -30.236654
#         J = +16.052632
#      dm_c = +1.907402
#     dm_r0 = -0.453695
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.270408
#      dm_b = -30.315788
#         J = +16.052632
#      dm_c = +1.909563
#     dm_r0 = -0.454966
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271034
#      dm_b = -30.319745
#         J = +16.052632
#      dm_c = +1.909671
#     dm_r0 = -0.455030
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271065
#      dm_b = -30.319943
#         J = +16.052632
#      dm_c = +1.909676
#     dm_r0 = -0.455033
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -4.271066
#      dm_b = -30.319953
#         J = +16.052632
#      dm_c = +1.909676
#     dm_r0 = -0.455033
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1528.71028816</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 287</td>
#                 <td title="Number of call in last migrad">NCALLS = 53</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 819.479045332</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 50.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#iDXxnEpapv').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>1.471617e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.000000e+00</td>
#                 <td>9.065598e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.605263e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>2.867139e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>8.000000e-02</td>
#                 <td>1.497785e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="iDXxnEpapv" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 1.472e-01 &  &  &  &  & \\
# \hline
# 2 & $dm_{b}$ & 3.000e+00 & 9.066e-01 &  &  &  &  & \\
# \hline
# 3 & J & 1.605e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 2.867e-02 &  &  &  &  & \\
# \hline
# 5 & $dm_{r0}$ & 8.000e-02 & 1.498e-02 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: Exception Occured
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +3.000000
#         J = +16.052632
#      dm_c = +0.999226
#     dm_r0 = +0.080000
#
#   return self.minuit.migrad(**kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-3ec441928555> in <module>()
#      26     valid = False
#      27     while not valid:
# ---> 28         BF = M.migrad_min()
#      29         valid = BF[0]['is_valid']
#      30         if M.minuit.tol>1e8 and not valid: break
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in migrad_min(self, **kwargs)
#      79         def migrad_min(self, **kwargs):
#      80                 self.migrad_args = kwargs
# ---> 81                 return self.minuit.migrad(**kwargs)
#      82
#      83         def minos_profile(self, var, **kwargs):
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.migrad (iminuit/_libiminuit.cpp:5250)()
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in <lambda>(dm_a, dm_b, J, dm_c, dm_r0)
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in __call__(self, *par_array)
#      42                                 for i,key in enumerate(self.free_pars.keys()):
#      43                                         self.sigma.setparams(key, par_array[i])
# ---> 44                                 S = self.compute()
#      45                                 #self._store(S, *par_array)
#      46                         return S
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in compute(self)
#      59         #in case of an array of Js, one should write another scan function
#      60         #so it might be that here only the R parallelization is in order
# ---> 61         S = dv**2 + self.sigma.compute(R) #this is an array like R array
#      62         res = np.log(S) + ((v-vsys)**2)/S
#      63         return res.sum() / 2.
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in compute(self, R)
#      63                 sigma2 = np.zeros_like(R)
#      64                 for i,rr in enumerate(R):
# ---> 65                         integral = quad(self.integrand, rr, np.inf, args=(rr,))[0]
#      66                         I_of_R = self.stellar.surface_brightness(rr)
#      67                         sigma2[i] = integral / I_of_R / Jred
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     313     if (weight is None):
#     314         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 315                        points)
#     316     else:
#     317         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     380             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     381         else:
# --> 382             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     383     else:
#     384         if infbounds != 0:
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in integrand(self, s, R, **kwargs)
#      48         r0 = kwargs['r0'] if 'r0' in kwargs else self.dm.r0
#      49         rh = kwargs['rh'] if 'rh' in kwargs else self.stellar.rh
# ---> 50         val = self.stellar.density(s/rh) * self.dm.mass(s/r0) * self.kernel(s, R) / s
#      51         return val
#      52
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/profiles.pyc in __call__(self, r, R)
#     234         def __call__(self, r, R):
#     235                 beta = self.beta
# --> 236                 return cyfuncs.func_constant_kernel(r, R, beta)
#     237
#     238 class OMKernel(AnisotropyKernel):
#
# KeyboardInterrupt:

# %%
interp_L = interp(J_arr, L_arr-L_arr.min())
for par in parameters:
    parname = par.split('_')[-1]
    exec( 'interp_{p} = interp(J_arr, {p}_arr)'.format(p=parname))

# %%
for par in parameters:
    parname = par.split('_')[-1]
    exec( '{p}_arr = np.delete({p}_arr,3)'.format(p=parname))

# %%
eval_Like_J = np.linspace(J_arr.min(), J_arr.max(), 1e3)
min_Like_J = interp_L(eval_Like_J).min()
Jmin = eval_Like_J[ np.where( interp_L(eval_Like_J) == min_Like_J )[0][0] ]
J_plt = np.linspace(J_arr.min(),J_arr.max())

# %% [raw]
# sortr = np.argsort(r_arr)
# interp_rL = interp(r_arr[sortr], L_arr[sortr]-L_arr.min())
# r_plt = np.linspace(r_arr.min(), r_arr.max())

# %% [raw]
# for i in range(1,r_arr.size):
#     if J_new[i-1] < Jmin < J_new[i]:
#         print r_arr[i-1], Jr, r_arr[i]
#         ibef = i-1
#         iaft = i

# %% [raw]
# plt.plot(r_arr, L_arr-L_arr.min());
# plt.plot(Jr, 0, 'r*', markersize=10, label=r'MLE: $r_s$ = %.2f'%Jr)
# plt.plot(rs, 0, 'b*', markersize=10, label='True : $r_s$ = %.2f'%rs);
# plt.plot(r_arr, L_arr-L_arr.min(), 'k|', markersize=20, label='interpolated points')
# plt.ylabel(r'$\mathcal{L(J)}$', fontsize=16)
# plt.xlabel(r'$r_s$', fontsize=16)
# plt.hlines(0, r_arr.min(), r_arr.max(), linestyle='--', color='k')
# plt.hlines(0.5, 0, r_arr.max(), linestyle='--', color='r', label=r'$1-\sigma$')
# plt.hlines(2.0, 0, r_arr.max(), linestyle='--', color='g', label=r'$2-\sigma$')
# plt.hlines(4.5, 0, r_arr.max(), linestyle='--', color='c', label=r'$3-\sigma$')
# plt.xlim(0,1);
# plt.ylim(-0.5,10);
# plt.legend(numpoints=1).get_frame().set_facecolor('w');
# #plt.savefig('results/Like_r.png', format='png', dpi=300);

# %% [raw]
# plt.plot(J_plt, interp_r(J_plt))
# plt.plot(Jmin, Jr, 'r*', markersize=10, label=r'MLE: $\mathcal{J}$ = %.2f, $r_s$ = %.2f'%(Jmin, Jr))
# plt.plot(Jtrue, rs, 'b*', markersize=10, label='True : $\mathcal{J}$ = %.2f, $r_s$ = %.2f'%(Jtrue, rs))
# J1L = Jmin - 0.11
# r1L = interp_r(J1L)
# plt.plot(J1L, r1L, 'y*', markersize=10, label=r'$r_s$ = %.2f : $r_s$ at $\mathcal{J} - 1\sigma$'%r1L)
# plt.plot(J_new, r_arr, 'k|', markersize=20, label='interpolated points')
# plt.xlabel(r'$\mathcal{J}$', fontsize=16)
# plt.ylabel(r'$r_s$', fontsize=16)
# plt.legend(numpoints=1)
# plt.ylim(0,0.5);
# plt.xlim(16.5,17.5);
# #plt.savefig('results/J_r.png', format='png', dpi=300);

# %%
Jr = float(interp_r0(Jmin))
Ja = float(interp_a(Jmin))
Jb = float(interp_b(Jmin))
Jc = float(interp_c(Jmin))
#Jbeta = float(interp_beta(Jmin))

# %%
dm.r0 = Jr
dm.a = Ja
dm.b = Jb
dm.c = Jc
minrho = lambda rho : abs(Jmin - np.log10( dm.Jfactor(**dwarf_props) ) - 2*rho)
Jrho = float(10**minimize_scalar(minrho).x)

# %%
print 'r = %.2f, rho = %.2e, a = %.2f, b = %.2f, c = %.2f'%(Jr, Jrho, Ja, Jb, Jc)
#print 'r = %.2f, rho = %.2e , c = %.2f'%(Jr, Jrho ,Jc)

# %%
for i,c in enumerate([0.5,2.0,4.5]):
    exec('J%ssL = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, J_arr.min(), Jmin) - Jmin))
    exec('J%ssR = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, Jmin, J_arr.max()) - Jmin))

# %%
plt.plot(J_plt, interp_L(J_plt))
plt.hlines(0, J_plt.min(), J_plt.max(), linestyles='dashed')
plt.plot(Jmin, 0, 'b^', markersize=10, label=r'$\mathcal{J}_{MLE}$ = %.2f'%Jmin)
plt.plot(16.72, 0, 'rd', markersize=6, label=r'$\mathcal{J}_{TRUE}$ = 16.72')
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    JL, JR = eval('J%ssL'%str(i+1)), eval('J%ssR'%str(i+1))
    plt.hlines(h, J_plt.min(), J_plt.max(), linestyles='dashed', colors=c,
              label=r'$%i-\sigma$'%(i+1)+'\t'+'[%2s,%2s]'%(str(JL),str(JR)))
plt.legend(numpoints=1,fontsize=14).get_frame().set_facecolor('w')
plt.text(15.5, 7,'a = %.2f (1)'%Ja +'\n'+
                 'b = %.2f (3)'%Jb +'\n'+
                 'c = %.2f (1)'%Jc +'\n'+
                 r'$r_s$ = %.2f (0.35)'%Jr +'\n'+
                 r'$\rho_s$ = %.2e'%Jrho +'\n     (7.55e+07)')

plt.ylim(-0.5,12);
#plt.xlim(16.3,17.5);
#plt.savefig('results/LikeJ_rabcBeta.png',format='png',dpi=300);
