# %%
import numpy as np
from math import sqrt,log10, log
import pylab as plt
from scipy.interpolate import interp1d as interp
from scipy.optimize import brentq, minimize_scalar
from profiles import build_profile, build_kernel
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter

# %matplotlib inline

# %%
directory = '/home/andrea/Desktop/work/DWARF/dsphsim/'
rh = 0.04
D = 39.81
theta = 2*rh/D
dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf}

# %% [markdown]
# ## True values

# %%
dm_true = build_profile('NFW')
rvmax = 0.757
vmax = 10.4
rs = rvmax/2.163
rhos = 4.625 * (vmax/rs)**2 / (4*np.pi*4.302e-6)
dm_true.r0 = rs
dm_true.rho0 = rhos
Jtrue = log10(dm_true.Jfactor(**dwarf_props))
print 'rs = %.2f, rhos = %.2e, J = %g'%(rs,rhos,Jtrue)
# Out:
# rs = 0.35, rhos = 7.55e+07, J = 16.724

# %%
dm = build_profile('NFW', r0=rs)
st = build_profile('plummer',rh=rh) # Plummer Stellar profile
kr = build_kernel('iso') # isotropic kernel
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

# %%
R, v = np.loadtxt(directory+'Ret2_data/dsph_001.txt',usecols=(5, 7),unpack=True)
vnan = np.isnan(v)
v = v[~vnan]
R = R[~vnan]
dv = np.zeros_like(v)

# %%
LL = GaussianLikelihood([R, v, dv, 0.], Sigma)
LL.set_free('dm_r0')
LL.set_free('dm_a')
LL.set_free('dm_b')
LL.set_free('dm_c')
#LL.set_free('ker_beta')

# %%
J_array = np.linspace(15, 19, 30)
L_arr = np.empty([0])
parameters = [par.split('_')[-1] for par in LL.free_pars.keys()]
for par in parameters:
    exec( '%s_arr = np.empty([0])'%par)

# %%
parameters
# Out:
# ['a', 'b', 'J', 'c', 'r0']

# %%
for j,J in enumerate(J_array):
    M = MinuitFitter(LL)
    # J
    M.set_value('J',J)
    M.set_fixed('J')
    # r0
    M.set_value('dm_r0',rh*8)
    M.set_error('dm_r0',0.01)
    # a
    M.set_value('dm_a',0.5)
    M.set_error('dm_a',0.01)
    M.set_bound('dm_a',(0.,2))
    # b
    M.set_value('dm_b',3.5)
    M.set_error('dm_b',0.01)
    M.set_bound('dm_b',(0.,10))
    # c
    M.set_value('dm_c',0.5)
    M.set_error('dm_c',0.01)
    M.set_bound('dm_c',(0.,3))
    # beta
    #M.set_value('ker_beta',0.)
    #M.set_error('ker_beta',0.01)
    
    M.settings['print_level'] = 1
    M.set_minuit(tol=1e4,strategy=1)
    
    valid = False
    while not valid:
        BF = M.migrad_min()
        valid = BF[0]['is_valid']
        if M.minuit.tol>1e5 and not valid:
            break
        else:
            M.minuit.tol *= 10
    else:
        if not np.isnan(BF[0]['edm']):
            L_arr = np.append(L_arr, BF[0]['fval'])
            for n,par in enumerate(parameters):
                exec( "{0}_arr = np.append({0}_arr, BF[1][n]['value'])".format(par))
# Out:
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.881887
#      dm_b = +9.982134
#         J = +15.000000
#      dm_c = +0.023548
#     dm_r0 = -70.677256
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.200457
#      dm_b = +9.784005
#         J = +15.000000
#      dm_c = +0.018508
#     dm_r0 = -74.235044
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.176847
#      dm_b = +9.768444
#         J = +15.000000
#      dm_c = +0.022646
#     dm_r0 = -74.412933
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.175701
#      dm_b = +9.767652
#         J = +15.000000
#      dm_c = +0.022864
#     dm_r0 = -74.421827
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.175644
#      dm_b = +9.767612
#         J = +15.000000
#      dm_c = +0.022875
#     dm_r0 = -74.422272
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.175641
#      dm_b = +9.767610
#         J = +15.000000
#      dm_c = +0.022875
#     dm_r0 = -74.422294
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.175641
#      dm_b = +9.767610
#         J = +15.000000
#      dm_c = +0.022875
#     dm_r0 = -74.422295
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.175641
#      dm_b = +9.767610
#         J = +15.000000
#      dm_c = +0.022875
#     dm_r0 = -74.422296
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1218.35116013</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 87</td>
#                 <td title="Number of call in last migrad">NCALLS = 74</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 435.355144832</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#hyNaUiAbqR').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.697635e-01</td>
#                 <td>4.949237e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.226133e+00</td>
#                 <td>6.704564e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>2.517427e-01</td>
#                 <td>1.899858e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.784965e-01</td>
#                 <td>2.419296e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="hyNaUiAbqR" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.698e-01 & 4.949e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.226e+00 & 6.705e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 2.517e-01 & 1.900e-01 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.785e-01 & 2.419e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.876067
#      dm_b = +9.981483
#         J = +15.000000
#      dm_c = +0.022983
#     dm_r0 = -70.702054
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.196774
#      dm_b = +9.781666
#         J = +15.000000
#      dm_c = +0.019041
#     dm_r0 = -74.261082
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.173358
#      dm_b = +9.766019
#         J = +15.000000
#      dm_c = +0.023237
#     dm_r0 = -74.439033
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.172223
#      dm_b = +9.765223
#         J = +15.000000
#      dm_c = +0.023457
#     dm_r0 = -74.447930
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.172166
#      dm_b = +9.765183
#         J = +15.000000
#      dm_c = +0.023468
#     dm_r0 = -74.448375
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.172163
#      dm_b = +9.765181
#         J = +15.000000
#      dm_c = +0.023469
#     dm_r0 = -74.448398
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.172163
#      dm_b = +9.765181
#         J = +15.000000
#      dm_c = +0.023469
#     dm_r0 = -74.448399
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1218.35116013</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 128</td>
#                 <td title="Number of call in last migrad">NCALLS = 15</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 435.654513084</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#tczPmFeOas').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.697635e-01</td>
#                 <td>4.949237e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.226133e+00</td>
#                 <td>6.704564e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>2.517427e-01</td>
#                 <td>1.899858e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.784965e-01</td>
#                 <td>2.419296e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="tczPmFeOas" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.698e-01 & 4.949e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.226e+00 & 6.705e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 2.517e-01 & 1.900e-01 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.785e-01 & 2.419e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1218.35116013</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 13130</td>
#                 <td title="Number of call in last migrad">NCALLS = 15</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 435.654513084</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 50.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#FFF79A">True</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#ZAocasAEQd').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.697635e-01</td>
#                 <td>4.949237e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.226133e+00</td>
#                 <td>6.704564e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.500000e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>2.517427e-01</td>
#                 <td>1.899858e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.784965e-01</td>
#                 <td>2.419296e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="ZAocasAEQd" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.698e-01 & 4.949e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.226e+00 & 6.705e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.500e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 2.517e-01 & 1.900e-01 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.785e-01 & 2.419e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.250617
#      dm_b = +1.590523
#         J = +15.137931
#      dm_c = +0.015566
#     dm_r0 = -18.052549
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.471585
#      dm_b = +1.938044
#         J = +15.137931
#      dm_c = +0.010451
#     dm_r0 = -18.978489
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.483967
#      dm_b = +1.956114
#         J = +15.137931
#      dm_c = +0.010222
#     dm_r0 = -19.024785
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.484589
#      dm_b = +1.957019
#         J = +15.137931
#      dm_c = +0.010210
#     dm_r0 = -19.027100
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.484620
#      dm_b = +1.957064
#         J = +15.137931
#      dm_c = +0.010210
#     dm_r0 = -19.027216
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.484622
#      dm_b = +1.957066
#         J = +15.137931
#      dm_c = +0.010210
#     dm_r0 = -19.027222
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.484622
#      dm_b = +1.957067
#         J = +15.137931
#      dm_c = +0.010210
#     dm_r0 = -19.027222
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1211.03082364</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 68</td>
#                 <td title="Number of call in last migrad">NCALLS = 55</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 71.9152863876</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#tmfNotwvpr').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.366490e-01</td>
#                 <td>4.483083e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.319281e+00</td>
#                 <td>9.384063e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.513793e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.202325e-01</td>
#                 <td>6.654570e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.662356e-01</td>
#                 <td>1.611510e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="tmfNotwvpr" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.366e-01 & 4.483e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.319e+00 & 9.384e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.514e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.202e-01 & 6.655e-02 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.662e-01 & 1.612e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.249728
#      dm_b = +1.589126
#         J = +15.137931
#      dm_c = +0.015612
#     dm_r0 = -18.048050
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.470386
#      dm_b = +1.936459
#         J = +15.137931
#      dm_c = +0.010491
#     dm_r0 = -18.973764
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.482755
#      dm_b = +1.954520
#         J = +15.137931
#      dm_c = +0.010261
#     dm_r0 = -19.020050
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.483376
#      dm_b = +1.955424
#         J = +15.137931
#      dm_c = +0.010250
#     dm_r0 = -19.022364
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.483407
#      dm_b = +1.955470
#         J = +15.137931
#      dm_c = +0.010249
#     dm_r0 = -19.022480
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.483409
#      dm_b = +1.955472
#         J = +15.137931
#      dm_c = +0.010249
#     dm_r0 = -19.022486
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1211.03082364</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 109</td>
#                 <td title="Number of call in last migrad">NCALLS = 15</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 71.8778597415</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 5.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#LAHvlWwWgt').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.366490e-01</td>
#                 <td>4.483083e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.319281e+00</td>
#                 <td>9.384063e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.513793e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.202325e-01</td>
#                 <td>6.654570e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.662356e-01</td>
#                 <td>1.611510e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="LAHvlWwWgt" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.366e-01 & 4.483e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.319e+00 & 9.384e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.514e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.202e-01 & 6.655e-02 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.662e-01 & 1.612e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1211.03082364</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 13111</td>
#                 <td title="Number of call in last migrad">NCALLS = 15</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 71.8778597415</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 50.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#FFF79A">True</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#McyRnODgGH').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>6.366490e-01</td>
#                 <td>4.483083e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>2.319281e+00</td>
#                 <td>9.384063e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.513793e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.202325e-01</td>
#                 <td>6.654570e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.662356e-01</td>
#                 <td>1.611510e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="McyRnODgGH" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 6.366e-01 & 4.483e-01 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 2.319e+00 & 9.384e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.514e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.202e-01 & 6.655e-02 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.662e-01 & 1.612e+00 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.673031
#      dm_b = +3.970267
#         J = +15.275862
#      dm_c = +0.093100
#     dm_r0 = -0.276750
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -nan
#      dm_b = -nan
#         J = +15.275862
#      dm_c = -nan
#     dm_r0 = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +nan
#         J = +15.275862
#      dm_c = +nan
#     dm_r0 = +nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.941385
#      dm_b = +9.229679
#         J = +15.275862
#      dm_c = +0.663453
#     dm_r0 = -6.352423
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.990470
#      dm_b = +7.720662
#         J = +15.275862
#      dm_c = +0.684030
#     dm_r0 = -6.691719
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.991836
#      dm_b = +7.629218
#         J = +15.275862
#      dm_c = +0.685065
#     dm_r0 = -6.708684
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.991901
#      dm_b = +7.624613
#         J = +15.275862
#      dm_c = +0.685117
#     dm_r0 = -6.709532
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.991904
#      dm_b = +7.624383
#         J = +15.275862
#      dm_c = +0.685119
#     dm_r0 = -6.709574
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.991905
#      dm_b = +7.624371
#         J = +15.275862
#      dm_c = +0.685119
#     dm_r0 = -6.709576
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.991905
#      dm_b = +7.624371
#         J = +15.275862
#      dm_c = +0.685120
#     dm_r0 = -6.709576
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1200.27869432</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 109</td>
#                 <td title="Number of call in last migrad">NCALLS = 96</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 1.88383479932</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.5</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#IyTHXlBLMs').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>7.526177e-01</td>
#                 <td>9.127393e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.797915e+00</td>
#                 <td>6.827859e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.527586e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.062841e-01</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.334886e-01</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="IyTHXlBLMs" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 7.526e-01 & 9.127e-02 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 3.798e+00 & 6.828e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.528e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.063e-01 &   nan &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 4.335e-01 &   nan &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.752618
#      dm_b = +3.797915
#         J = +15.275862
#      dm_c = +nan
#     dm_r0 = +0.433489
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.752618
#      dm_b = +3.797915
#         J = +15.275862
#      dm_c = +0.306284
#     dm_r0 = +nan
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1200.27869432</td>
# ...
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#FFF79A">True</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#dyPlTYzJkq').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>4.747981e-02</td>
#                 <td>2.327791e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.069973e+00</td>
#                 <td>1.993249e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.858621e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.252937e-01</td>
#                 <td>1.873453e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>6.718122e-02</td>
#                 <td>1.581537e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="dyPlTYzJkq" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 4.748e-02 & 2.328e-02 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 3.070e+00 & 1.993e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.859e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.253e-01 & 1.873e-01 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 6.718e-02 & 1.582e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 1208.24122132</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 13172</td>
#                 <td title="Number of call in last migrad">NCALLS = 17</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 13.0722035034</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 50.0</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#qsiKJGLKVj').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>4.747981e-02</td>
#                 <td>2.327791e-02</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>2.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>3.069973e+00</td>
#                 <td>1.993249e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.858621e+01</td>
#                 <td>1.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td>FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>3.252937e-01</td>
#                 <td>1.873453e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0</td>
#                 <td>3.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>6.718122e-02</td>
#                 <td>1.581537e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td></td>
#                 <td></td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="qsiKJGLKVj" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 4.748e-02 & 2.328e-02 &  &  & 0.000e+00 & 2.000e+00 & \\
# \hline
# 2 & $dm_{b}$ & 3.070e+00 & 1.993e-01 &  &  & 0.000e+00 & 1.000e+01 & \\
# \hline
# 3 & J & 1.859e+01 & 1.000e+00 &  &  &  &  & FIXED\\
# \hline
# 4 & $dm_{c}$ & 3.253e-01 & 1.873e-01 &  &  & 0.000e+00 & 3.000e+00 & \\
# \hline
# 5 & $dm_{r0}$ & 6.718e-02 & 1.582e-01 &  &  &  &  & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.050345
#      dm_b = +3.128067
#         J = +18.724138
#      dm_c = +0.336840
#     dm_r0 = -0.019965
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = -nan
#      dm_b = -nan
#         J = +18.724138
#      dm_c = -nan
#     dm_r0 = -nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +nan
#         J = +18.724138
#      dm_c = +nan
#     dm_r0 = +nan
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.042264
#      dm_b = +2.986094
#         J = +18.724138
#      dm_c = +0.290299
#     dm_r0 = -0.000778
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.036683
#      dm_b = +2.928801
#         J = +18.724138
#      dm_c = +0.274029
#     dm_r0 = -0.001088
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.000371
#      dm_b = +3.118552
#         J = +18.724138
#      dm_c = +0.118683
#     dm_r0 = +0.024360
#
#   return self.minuit.migrad(**kwargs)
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:356: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg, IntegrationWarning)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.000104
#      dm_b = +3.125890
#         J = +18.724138
#      dm_c = +0.112061
#     dm_r0 = +0.025043
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.000095
#      dm_b = +3.126257
#         J = +18.724138
#      dm_c = +0.111735
#     dm_r0 = +0.025077
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.000094
#      dm_b = +3.126275
#         J = +18.724138
#      dm_c = +0.111719
#     dm_r0 = +0.025079
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.000094
#      dm_b = +3.126276
#         J = +18.724138
#      dm_c = +0.111718
#     dm_r0 = +0.025079
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:81: RuntimeWarning: Exception Occured
# fcn is called with following arguments:
#      dm_a = +0.000094
#      dm_b = +3.126276
#         J = +18.724138
#      dm_c = +0.111718
#     dm_r0 = +0.025079
#
#   return self.minuit.migrad(**kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-e760d32868bb> in <module>()
#      28     valid = False
#      29     while not valid:
# ---> 30         BF = M.migrad_min()
#      31         valid = BF[0]['is_valid']
#      32         if M.minuit.tol>1e5 and not valid:
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in migrad_min(self, **kwargs)
#      79         def migrad_min(self, **kwargs):
#      80                 self.migrad_args = kwargs
# ---> 81                 return self.minuit.migrad(**kwargs)
#      82
#      83         def minos_profile(self, var, **kwargs):
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.migrad (iminuit/_libiminuit.cpp:5250)()
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/fitter.pyc in <lambda>(dm_a, dm_b, J, dm_c, dm_r0)
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in __call__(self, *par_array)
#      42                                 for i,key in enumerate(self.free_pars.keys()):
#      43                                         self.sigma.setparams(key, par_array[i])
# ---> 44                                 S = self.compute()
#      45                                 #self._store(S, *par_array)
#      46                         return S
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/likelihood.pyc in compute(self)
#      59         #in case of an array of Js, one should write another scan function
#      60         #so it might be that here only the R parallelization is in order
# ---> 61         S = dv**2 + self.sigma.compute(R) #this is an array like R array
#      62         res = np.log(S) + ((v-vsys)**2)/S
#      63         return res.sum() / 2.
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in compute(self, R)
#      63                 sigma2 = np.zeros_like(R)
#      64                 for i,rr in enumerate(R):
# ---> 65                         integral = quad(self.integrand, rr, np.inf, args=(rr,))[0]
#      66                         I_of_R = self.stellar.surface_brightness(rr)
#      67                         sigma2[i] = integral / I_of_R / Jred
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     313     if (weight is None):
#     314         retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
# --> 315                        points)
#     316     else:
#     317         retval = _quad_weight(func, a, b, args, full_output, epsabs, epsrel,
#
# /usr/local/lib/python2.7/dist-packages/scipy/integrate/quadpack.pyc in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     380             return _quadpack._qagse(func,a,b,args,full_output,epsabs,epsrel,limit)
#     381         else:
# --> 382             return _quadpack._qagie(func,bound,infbounds,args,full_output,epsabs,epsrel,limit)
#     383     else:
#     384         if infbounds != 0:
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/dispersion.pyc in integrand(self, s, R, **kwargs)
#      48         r0 = kwargs['r0'] if 'r0' in kwargs else self.dm.r0
#      49         rh = kwargs['rh'] if 'rh' in kwargs else self.stellar.rh
# ---> 50         val = self.stellar.density(s/rh) * self.dm.mass(s/r0) * self.kernel(s, R) / s
#      51         return val
#      52
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/cython/profiles.pyc in mass(self, x)
#     181         def mass(self, x):
#     182                 a, b, c = self.a, self.b, self.c
# --> 183                 return cyfuncs.mass_func(x, a, b, c)
#     184
#     185 ##############################################################################
#
# KeyboardInterrupt:

# %%
plt.plot(J_arr,L_arr-min(L_arr))
plt.hlines(0, J_arr.min(), J_arr.max(), linestyles='dashed')
plt.plot(16.72, 0, 'rd', markersize=6)
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    plt.hlines(h, J_arr.min(), J_arr.max(), linestyles='dashed', colors=c)
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/collections.py:548: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == 'face':

# %%
interp_L = interp(J_arr, L_arr-L_arr.min())
for par in parameters:
    exec( 'interp_{0} = interp(J_arr, {0}_arr)'.format(par))

# %%
from scipy.interpolate import UnivariateSpline as spline

# %%
parameters
# Out:
# ['a', 'b', 'J', 'c', 'r0']

# %%
interp_L = spline(J_arr, L_arr-L_arr.min(), s=0.5)
for par in parameters:
    exec( 'interp_{0} = spline(J_arr, {0}_arr, s=0.5)'.format(par))

# %%
eval_Like_J = np.linspace(J_arr.min(), J_arr.max(), 1e3)
min_Like_J = interp_L(eval_Like_J).min()
Jmin = eval_Like_J[ np.where( interp_L(eval_Like_J) == min_Like_J )[0][0] ]
J_plt = np.linspace(J_arr.min(),J_arr.max())

# %%
Jr = float(interp_r0(Jmin))
Ja = float(interp_a(Jmin))
Jb = float(interp_b(Jmin))
Jc = float(interp_c(Jmin))
#Jbeta = float(interp_beta(Jmin))

# %%
dm.r0 = Jr
dm.a = Ja
dm.b = Jb
dm.c = Jc
minrho = lambda rho : abs(Jmin - np.log10( dm.Jfactor(**dwarf_props) ) - 2*rho)
Jrho = float(10**minimize_scalar(minrho).x)

# %%
print 'r = %.2f, rho = %.2e, a = %.2f, b = %.2f, c = %.2f'%(Jr, Jrho, Ja, Jb, Jc)
#print 'r = %.2f, rho = %.2e , c = %.2f'%(Jr, Jrho ,Jc)
# Out:
# r = 0.32, rho = 7.01e+08, a = 0.46, b = 3.15, c = 0.57

# %%
for i,c in enumerate([0.5,2.0,4.5]):
    exec('J%ssL = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, J_arr.min(), Jmin) - Jmin))
    exec('J%ssR = %.2f'%(i+1, brentq(lambda j : interp_L(j)-c, Jmin, J_arr.max()) - Jmin))

# %%
L_plt = interp_L(J_plt)
plt.plot(J_plt, L_plt)
plt.hlines(0, J_plt.min(), J_plt.max(), linestyles='dashed')
plt.plot(Jmin, 0, 'b^', markersize=10, label=r'$\mathcal{J}_{MLE}$ = %.2f'%Jmin)
plt.plot(16.72, 0, 'rd', markersize=6, label=r'$\mathcal{J}_{TRUE}$ = 16.72')
for i,(c,h) in enumerate(zip(['r','g','c'],[0.5,2.0,4.5])):
    JL, JR = eval('J%ssL'%str(i+1)), eval('J%ssR'%str(i+1))
    plt.hlines(h, J_plt.min(), J_plt.max(), linestyles='dashed', colors=c,
              label=r'$%i-\sigma$'%(i+1)+'\t'+'[%2s,%2s]'%(str(JL),str(JR)))
plt.legend(numpoints=1,fontsize=14).get_frame().set_facecolor('w')
plt.text(15.5, 7,'a = %.2f (1)'%Ja +'\n'+
                 'b = %.2f (3)'%Jb +'\n'+
                 'c = %.2f (1)'%Jc +'\n'+
                 r'$r_s$ = %.2f (0.35)'%Jr +'\n'+
                 r'$\rho_s$ = %.2e'%Jrho +'\n     (7.55e+07)')

plt.ylim(-0.5,20);
#plt.xlim(16.3,17.5);
#plt.savefig('results/LikeJ_rabc_20p.png',format='png',dpi=300);

# %%
plt.hist(R, bins=50);
plt.ylim(0, 10)
#plt.savefig('results/histR.png', dpi=300, format='png');;
# Out:
# (0, 10)
