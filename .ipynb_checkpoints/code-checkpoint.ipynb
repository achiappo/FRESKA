# %%
import numpy as np
from profiles import *
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter
from utils import *

# %%
homedir = '/home/andrea/Desktop/work/DWARF/Jvalue/project1/test/Isotrop_Core_nonPlum'
MockSize = 100
dataSize = 100
dset = 1
# enter model choice - cf. casedir (options 1,2,3,4)
mod = 1
theta = 0.5
D = 100

# %%
data = load_gaia(homedir, MockSize, dataSize, dset, mod, D, True)
# Out:
# Using  /home/andrea/Desktop/work/DWARF/Jvalue/project1/test/Isotrop_Core_nonPlum/data/gs100_bs050_rcrs100_rarcinf_core_0400mpc3_df_100_1.dat

# %%
kinematic = data[0:3]
rh = data[-3]
r0_true = data[-2]
rho0_true = data[-1]

# %%
dm = build_profile('Zhao', a=1., b=3., c=0.) # Cored DM profile
st = build_profile('plummer', **{'c':1, 'rh':rh}) # non-Plummer Stellar profile
kr = build_kernel('iso') # isotropic kernel

# %%
dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf, 'errs':False}

# %%
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

# %%
LL = GaussianLikelihood(kinematic, Sigma)

# %%
LL.set_free('dm_r0')

# %%
LL.sigma.setparams('J',18)

# %%
global global_loglike
global_loglike = LL
M = MinuitFitter(LL)

# %%
M.set_value('J',19)
M.set_value('dm_r0',rh/2.)
M.set_error('J',0.01)
M.set_bound('J',(15,22))
M.set_error('dm_r0',0.01)
M.set_bound('dm_r0',(kinematic[0].min(),kinematic[0].max()))
M.settings['print_level'] = 1

# %% [raw]
# M.set_free('dm_c')
# M.set_error('dm_c',0.01)
# M.set_bound('dm_c',(0.001,5))

# %%
M.settings
# Out:
# {'J': 19,
#  'dm_r0': 0.5,
#  'error_J': 0.01,
#  'error_dm_r0': 0.01,
#  'errordef': 0.5,
#  'limit_J': (15, 22),
#  'limit_dm_r0': (0.075304685777181218, 8.2368209066605313),
#  'pedantic': False,
#  'print_level': 1}

# %%
M.set_minuit(**{'tol':1e2,'strategy':2})

# %%
M.migrad_min()

# %%
M.minos_profile('J')

# %%
# %load code.py
# %timeit -t

import numpy as np
from profiles import *
from dispersion import SphericalJeansDispersion
from likelihood import GaussianLikelihood
from fitter import MinuitFitter
from utils import *

homedir = '/home/andrea/Desktop/work/DWARF/Jvalue/project1/test/Isotrop_Core_nonPlum'
MockSize = 100
dataSize = 100
dset = 1
# enter model choice - cf. casedir (options 1,2,3,4)
mod = 1
theta = 0.5
D = 100

data = load_gaia(homedir, MockSize, dataSize, dset, mod, D, True)

kinematic = data[0:3]
rh = data[-3]
r0_true = data[-2]
rho0_true = data[-1]

dm = build_profile('Zhao', a=1., b=3., c=0.) # Cored DM profile
st = build_profile('plummer', **{'c':1, 'rh':rh}) # non-Plummer Stellar profile
kr = build_kernel('iso') # isotropic kernel

dwarf_props = {'D':D, 'theta':theta, 'rt':np.inf, 'errs':False}
Sigma = SphericalJeansDispersion(dm, st, kr, dwarf_props)

LL = GaussianLikelihood(kinematic, Sigma)
LL.set_free('dm_r0')
LL.set_free('dm_a')
LL.set_free('dm_b')
LL.set_free('dm_c')

global global_loglike
global_loglike = LL
M = MinuitFitter(LL)

# J
M.set_value('J',19)
M.set_error('J',0.01)
M.set_bound('J',(15,22))
# r0
M.set_value('dm_r0',1.)
M.set_error('dm_r0',0.01)
M.set_bound('dm_r0',(kinematic[0].min(),kinematic[0].max()))
# a
M.set_value('dm_a',1.)
M.set_error('dm_a',0.01)
M.set_bound('dm_a',(1e-10,10))
# b
M.set_value('dm_b',1.)
M.set_error('dm_b',0.01)
M.set_bound('dm_b',(1e-10,10))
# c
M.set_value('dm_c',1.)
M.set_error('dm_c',0.01)
M.set_bound('dm_c',(1e-10,10))

M.settings['print_level'] = 1

M.set_minuit(**{'tol':1e2,'strategy':2})
M.migrad_min()
M.minos_profile('J',**{'bound':(18,22),'subtract_min':True})
# Out:
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:295: UserWarning: The algorithm does not converge.  Roundoff error is detected
#   in the extrapolation table.  It is assumed that the requested tolerance
#   cannot be achieved, and that the returned result (if full_output = 1) is
#   the best which can be obtained.
#   warnings.warn(msg)
# likelihood.py:58: RuntimeWarning: invalid value encountered in log
#   res = np.log(S) + ((v-v.mean())**2)/S
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +4.885791
#         J = +19.024997
#      dm_c = +3.071938
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:295: UserWarning: The integral is probably divergent, or slowly convergent.
#   warnings.warn(msg)
# dispersion.py:59: RuntimeWarning: invalid value encountered in sqrt
#   Jred = np.sqrt(self.dm.Jreduced(D, theta, rt, errs))
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +5.111884
#         J = +19.026246
#      dm_c = +3.195186
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +5.123187
#         J = +19.026308
#      dm_c = +3.201382
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +5.123752
#         J = +19.026312
#      dm_c = +3.201692
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +5.123780
#         J = +19.026312
#      dm_c = +3.201708
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +5.123782
#         J = +19.026312
#      dm_c = +3.201708
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.927946
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.051393
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +2.973554
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# Using  /home/andrea/Desktop/work/DWARF/Jvalue/project1/test/Isotrop_Core_nonPlum/data/gs100_bs050_rcrs100_rarcinf_core_0400mpc3_df_100_1.dat
# fitter.py:69: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +0.044490
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   return self.minuit.migrad(**kwargs)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = 357.950724824</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 140</td>
#                 <td title="Number of call in last migrad">NCALLS = 127</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = 14.2228967356</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.005</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#fCVLDAQxQK').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>5.559795e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>1.000000e+00</td>
#                 <td>6.173024e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.900000e+01</td>
#                 <td>1.223696e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>15.0</td>
#                 <td>22.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>5.185249e-01</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>1.000000e+00</td>
#                 <td>4.695902e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0753046857772</td>
#                 <td>8.23682090666</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="fCVLDAQxQK" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 & 5.560e+00 &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 2 & $dm_{b}$ & 1.000e+00 & 6.173e-01 &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 3 & J & 1.900e+01 & 1.224e-01 &  &  & 1.500e+01 & 2.200e+01 & \\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 & 5.185e-01 &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 5 & $dm_{r0}$ & 1.000e+00 & 4.696e+00 &  &  & 7.530e-02 & 8.237e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.hesse()
# /usr/lib/python2.7/dist-packages/scipy/integrate/quadpack.py:295: UserWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   warnings.warn(msg)
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.hesse()
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +nan
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.hesse()
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +nan
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.hesse()
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +nan
#     dm_r0 = +1.000000
#
#   self.minuit.hesse()
# fitter.py:73: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +nan
#
#   self.minuit.hesse()
# fitter.py:73: HesseFailedWarning: HESSE Failed. Covariance and GlobalCC will not be available
#   self.minuit.hesse()
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#hXHztUvRNo').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>1.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>1.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.900000e+01</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>15.0</td>
#                 <td>22.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>1.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>1.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0753046857772</td>
#                 <td>8.23682090666</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="hXHztUvRNo" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 1.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 2 & $dm_{b}$ & 1.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 3 & J & 1.900e+01 &   nan &  &  & 1.500e+01 & 2.200e+01 & \\
# \hline
# 4 & $dm_{c}$ & 1.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 5 & $dm_{r0}$ & 1.000e+00 &   nan &  &  & 7.530e-02 & 8.237e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.migrad(**self.migrad_args)
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.migrad(**self.migrad_args)
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +nan
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.migrad(**self.migrad_args)
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +nan
#      dm_c = +1.000000
#     dm_r0 = +1.000000
#
#   self.minuit.migrad(**self.migrad_args)
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +nan
#     dm_r0 = +1.000000
#
#   self.minuit.migrad(**self.migrad_args)
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +1.000000
#      dm_b = +1.000000
#         J = +19.000000
#      dm_c = +1.000000
#     dm_r0 = +nan
#
#   self.minuit.migrad(**self.migrad_args)
# Function not at minimum. Running migrad first.
# fitter.py:77: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +nan
#         J = +nan
#      dm_c = +nan
#     dm_r0 = +nan
#
#   self.minuit.migrad(**self.migrad_args)
# <hr>
#         <table>
#             <tr>
#                 <td title="Minimum value of function">FCN = nan</td>
#                 <td title="Total number of call to FCN so far">TOTAL NCALL = 339</td>
#                 <td title="Number of call in last migrad">NCALLS = 137</td>
#             </tr>
#             <tr>
#                 <td title="Estimated distance to minimum">EDM = nan</td>
#                 <td title="Maximum EDM definition of convergence">GOAL EDM = 0.005</td>
#                 <td title="Error def. Amount of increase in FCN to be defined as 1 standard deviation">
#                 UP = 0.5</td>
#             </tr>
#         </table>
#
#         <table>
#             <tr>
#                 <td align="center" title="Validity of the migrad call">Valid</td>
#                 <td align="center" title="Validity of parameters">Valid Param</td>
#                 <td align="center" title="Is Covariance matrix accurate?">Accurate Covar</td>
#                 <td align="center" title="Positive definiteness of covariance matrix">PosDef</td>
#                 <td align="center" title="Was covariance matrix made posdef by adding diagonal element">Made PosDef</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#FF7878">False</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#             <tr>
#                 <td align="center" title="Was last hesse call fail?">Hesse Fail</td>
#                 <td align="center" title="Validity of covariance">HasCov</td>
#                 <td align="center" title="Is EDM above goal EDM?">Above EDM</td>
#                 <td align="center"></td>
#                 <td align="center" title="Did last migrad call reach max call limit?">Reach calllim</td>
#             </tr>
#             <tr>
#                 <td align="center" style="background-color:#FF7878">True</td>
#                 <td align="center" style="background-color:#92CCA6">True</td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#                 <td align="center"></td>
#                 <td align="center" style="background-color:#92CCA6">False</td>
#             </tr>
#         </table>
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#qFUXfkdyhQ').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>nan</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>nan</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>nan</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>15.0</td>
#                 <td>22.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>nan</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>nan</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0753046857772</td>
#                 <td>8.23682090666</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="qFUXfkdyhQ" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ &   nan &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 2 & $dm_{b}$ &   nan &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 3 & J &   nan &   nan &  &  & 1.500e+01 & 2.200e+01 & \\
# \hline
# 4 & $dm_{c}$ &   nan &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 5 & $dm_{r0}$ &   nan &   nan &  &  & 7.530e-02 & 8.237e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# <hr>
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +nan
#      dm_b = +5.000000
#         J = +18.500000
#      dm_c = +5.000000
#     dm_r0 = +4.156063
#
#   self.minuit.hesse()
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5.000000
#      dm_b = +nan
#         J = +18.500000
#      dm_c = +5.000000
#     dm_r0 = +4.156063
#
#   self.minuit.hesse()
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5.000000
#      dm_b = +5.000000
#         J = +nan
#      dm_c = +5.000000
#     dm_r0 = +4.156063
#
#   self.minuit.hesse()
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5.000000
#      dm_b = +5.000000
#         J = +18.500000
#      dm_c = +nan
#     dm_r0 = +4.156063
#
#   self.minuit.hesse()
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5.000000
#      dm_b = +5.000000
#         J = +18.500000
#      dm_c = +5.000000
#     dm_r0 = +nan
#
#   self.minuit.hesse()
# fitter.py:78: RuntimeWarning: fcn returns Nan
# fcn is called with following arguments:
#      dm_a = +5.000000
#      dm_b = +5.000000
#         J = +18.500000
#      dm_c = +5.000000
#     dm_r0 = +4.156063
#
#   self.minuit.hesse()
# fitter.py:78: HesseFailedWarning: HESSE Failed. Covariance and GlobalCC will not be available
#   self.minuit.hesse()
#         <table>
#             <tr>
#                 <td><a href="#" onclick="$('#kAFHwkOGnY').toggle()">+</a></td>
#                 <td title="Variable name">Name</td>
#                 <td title="Value of parameter">Value</td>
#                 <td title="Parabolic error">Parab Error</td>
#                 <td title="Minos lower error">Minos Error-</td>
#                 <td title="Minos upper error">Minos Error+</td>
#                 <td title="Lower limit of the parameter">Limit-</td>
#                 <td title="Upper limit of the parameter">Limit+</td>
#                 <td title="Is the parameter fixed in the fit">FIXED</td>
#             </tr>
#
#             <tr>
#                 <td>1</td>
#                 <td>dm_a</td>
#                 <td>5.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>2</td>
#                 <td>dm_b</td>
#                 <td>5.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>3</td>
#                 <td>J</td>
#                 <td>1.850000e+01</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>15.0</td>
#                 <td>22.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>4</td>
#                 <td>dm_c</td>
#                 <td>5.000000e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>1e-10</td>
#                 <td>10.0</td>
#                 <td></td>
#             </tr>
#
#             <tr>
#                 <td>5</td>
#                 <td>dm_r0</td>
#                 <td>4.156063e+00</td>
#                 <td>nan</td>
#                 <td>0.000000e+00</td>
#                 <td>0.000000e+00</td>
#                 <td>0.0753046857772</td>
#                 <td>8.23682090666</td>
#                 <td></td>
#             </tr>
#
#             </table>
#
#             <pre id="kAFHwkOGnY" style="display:none;">
#             <textarea rows="16" cols="50" onclick="this.select()" readonly>\begin{tabular}{|c|r|r|r|r|r|r|r|c|}
# \hline
#  & Name & Value & Para Error & Error+ & Error- & Limit+ & Limit- & FIXED\\
# \hline
# 1 & $dm_{a}$ & 5.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 2 & $dm_{b}$ & 5.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 3 & J & 1.850e+01 &   nan &  &  & 1.500e+01 & 2.200e+01 & \\
# \hline
# 4 & $dm_{c}$ & 5.000e+00 &   nan &  &  & 1.000e-10 & 1.000e+01 & \\
# \hline
# 5 & $dm_{r0}$ & 4.156e+00 &   nan &  &  & 7.530e-02 & 8.237e+00 & \\
# \hline
# \end{tabular}</textarea>
#             </pre>
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-c0b6cd406bb3> in <module>()
#      67 M.set_minuit(**{'tol':1e2,'strategy':2})
#      68 M.migrad_min()
# ---> 69 M.minos_profile('J',**{'bound':(18,22),'subtract_min':True})
#
# /home/andrea/Desktop/work/DWARF/ASTROJPY/fitter.py in minos_profile(self, var, **kwargs)
#      76                 print('Function not at minimum. Running migrad first.')
#      77                 self.minuit.migrad(**self.migrad_args)
# ---> 78                 self.minuit.hesse()
#      79                 var_array, Like, res = self.minuit.mnprofile(var, **kwargs)
#      80         return var_array, Like
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.hesse (iminuit/_libiminuit.cpp:5759)()
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.print_matrix (iminuit/_libiminuit.cpp:7713)()
#
# iminuit/_libiminuit.pyx in iminuit._libiminuit.Minuit.matrix (iminuit/_libiminuit.cpp:7508)()
#
# RuntimeError: Covariance is not valid. May be the last Hesse call failed?
